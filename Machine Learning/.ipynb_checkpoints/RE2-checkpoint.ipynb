# %%
import json
import pandas as pd
import os
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
tp='cle_radius.csv'
all_data=pd.read_csv(tp)
df=all_data.drop(['identifier/fips', 'identifier/apn', 'identifier/apnOrig', 'summary/propIndicator', 'summary/proptype','location/geoid', 'identifier/attomId', 'sale/amount/salecode', 'sale/amount/saledisclosuretype', 'address/matchCode', 'address/postal2', 'address/postal3', 'location/accuracy', 'address/country', 'sale/amount/saledocnum', 'summary/propLandUse', 'location/elevation' ], axis=1)
df.dtypes
df2=df.merge(income2, how='inner', on= 'address/postal1')
df2
# Out:
#       identifier/obPropId  LotSizeAcres address/countrySubd  \
# 0            2.172470e+13        8.2130                  OH
# 1            1.827130e+13        1.6500                  OH
# 2            2.428500e+13       17.1880                  OH
# 3            2.428510e+13       22.3100                  OH
# 4            1.827220e+13       25.9750                  OH
# 5            3.701350e+12        0.5700                  OH
# 6            1.819840e+13        2.0000                  OH
# 7            1.827180e+13        0.3246                  OH
# 8            1.821150e+13        0.4890                  OH
# 9            3.694920e+12        0.3719                  OH
# 10           1.827170e+13        1.6080                  OH
# 11           3.717810e+12        1.1000                  OH
# 12           1.827140e+13        1.0660                  OH
# 13           1.827170e+13        1.0000                  OH
# 14           1.827170e+13        6.8060                  OH
# 15           3.711530e+12        0.5400                  OH
# 16           1.104690e+12        0.5550                  OH
# 17           3.700230e+12        0.5500                  OH
# 18           1.827730e+13        5.0830                  OH
# 19           1.821620e+13        3.0940                  OH
# 20           1.827120e+13        0.4600                  OH
# 21           1.827130e+13       81.4600                  OH
# 22           2.453840e+13        0.3847                  OH
# 23           1.821130e+13        0.9710                  OH
# 24           1.827800e+13        1.6120                  OH
# 25           1.821150e+13        0.3271                  OH
# 26           1.827180e+13        0.3444                  OH
# 27           1.827170e+13        0.0661                  OH
# 28           2.958960e+12        0.1136                  OH
# 29           2.428500e+13        3.6500                  OH
# ...                   ...           ...                 ...
# 9954         1.822420e+13        1.8107                  OH
# 9955         1.822420e+13        2.1379                  OH
# 9956         2.758320e+11        1.2793                  OH
# 9957         1.828350e+13        0.2230                  OH
# 9958         1.828350e+13        0.1883                  OH
# 9959         3.291580e+12        6.3710                  OH
# 9960         2.048690e+13        0.1773                  OH
# 9961         1.568100e+12        0.1593                  OH
# 9962         3.694640e+12        1.7309                  OH
# 9963         5.030870e+12        0.2259                  OH
# 9964         1.537460e+12        0.2693                  OH
# 9965         1.465640e+12        0.6700                  OH
# 9966         5.258180e+12        0.4400                  OH
# 9967         2.241580e+12        0.2112                  OH
# 9968         4.707260e+11        0.4293                  OH
# 9969         3.706550e+12        0.2169                  OH
# 9970         1.494410e+13        0.2066                  OH
# 9971         1.556740e+12        0.9228                  OH
# 9972         1.447270e+13        0.2792                  OH
# 9973         3.647360e+11        0.6341                  OH
# 9974         1.823070e+13        0.5831                  OH
# 9975         1.431650e+13        0.3555                  OH
# 9976         1.822530e+13        0.2927                  OH
# 9977         1.194300e+12        0.2920                  OH
# 9978         1.194300e+12        0.4820                  OH
# 9979         5.351590e+12        1.0296                  OH
# 9980         1.823240e+13        0.9870                  OH
# 9981         1.442490e+13        1.6300                  OH
# 9982         3.699540e+12        0.3600                  OH
# 9983         1.026680e+12        0.3900                  OH
#
#                address/line1                address/line2    address/locality  \
# 0             11024 DOVER RD        APPLE CREEK, OH 44606         Apple Creek
# 1           7651 BUSS RD # A        APPLE CREEK, OH 44606         Apple Creek
# 2              LINCOLN WAY E        APPLE CREEK, OH 44606         Apple Creek
# 3                CHIPPEWA RD        APPLE CREEK, OH 44606         Apple Creek
# 4     3610 FREDERICKSBURG RD        APPLE CREEK, OH 44606         Apple Creek
# 5           12733 EMERSON RD        APPLE CREEK, OH 44606         Apple Creek
# 6        4353 S HONEYTOWN RD        APPLE CREEK, OH 44606         Apple Creek
# 7          114 SPRING RUN DR        APPLE CREEK, OH 44606         Apple Creek
# 8                208 MILL ST        APPLE CREEK, OH 44606         Apple Creek
# 9              732 W MAIN ST        APPLE CREEK, OH 44606         Apple Creek
# 10             5082 DOVER RD        APPLE CREEK, OH 44606         Apple Creek
# 11          10536 HACKETT RD        APPLE CREEK, OH 44606         Apple Creek
# 12          14950 HACKETT RD         APPLE CREEK,OH 44606         Apple Creek
# 13            2706 S CARR RD        APPLE CREEK, OH 44606         Apple Creek
# 14               9103 ELY RD        APPLE CREEK, OH 44606         Apple Creek
# 15            10216 DOVER RD        APPLE CREEK, OH 44606         Apple Creek
# 16            10532 DOVER RD        APPLE CREEK, OH 44606         Apple Creek
# 17              7562 BUSS RD        APPLE CREEK, OH 44606         Apple Creek
# 18              7970 BUSS RD        APPLE CREEK, OH 44606         Apple Creek
# 19            5455 OBERLY DR        APPLE CREEK, OH 44606         Apple Creek
# 20           8575 EMERSON RD        APPLE CREEK, OH 44606         Apple Creek
# 21          10043 EMERSON RD        APPLE CREEK, OH 44606         Apple Creek
# 22             31 SHANNON DR        APPLE CREEK, OH 44606         Apple Creek
# 23          12990 EMERSON RD        APPLE CREEK, OH 44606         Apple Creek
# 24            4767 S CARR RD        APPLE CREEK, OH 44606         Apple Creek
# 25        294 APPLE RIDGE DR        APPLE CREEK, OH 44606         Apple Creek
# 26         72 APPLE RIDGE DR        APPLE CREEK, OH 44606         Apple Creek
# 27               49 MAPLE ST        APPLE CREEK, OH 44606         Apple Creek
# 28            97 DOGWOOD CIR        APPLE CREEK, OH 44606         Apple Creek
# 29             5315 DOVER RD         APPLE CREEK,OH 44606         Apple Creek
# ...                      ...                          ...                 ...
# 9954       4550 W SPRAGUE RD              PARMA, OH 44134               Parma
# 9955       2580 W SPRAGUE RD          CLEVELAND, OH 44134           Cleveland
# 9956       4040 W SPRAGUE RD           CLEVELAND,OH 44134           Cleveland
# 9957       5280 ARLINGTON LN              PARMA, OH 44134               Parma
# 9958       5320 ARLINGTON LN              PARMA, OH 44134               Parma
# 9959      6810 ARBOR CT # 25              PARMA, OH 44134               Parma
# 9960          6160 KELLEY LN               PARMA,OH 44134               Parma
# 9961          6000 KELLEY LN              PARMA, OH 44134               Parma
# 9962      12100 W SPRAGUE RD              PARMA, OH 44130               Parma
# 9963            7881 NEIL DR              PARMA, OH 44130               Parma
# 9964        7871 E LINDEN LN              PARMA, OH 44130               Parma
# 9965        13994 BYRON BLVD          CLEVELAND, OH 44130           Cleveland
# 9966   13901 BENNINGTON BLVD  MIDDLEBURG HEIGHTS,OH 44130  Middleburg Heights
# 9967        7794 E LINDEN LN              PARMA, OH 44130               Parma
# 9968          7733 ALAN PKWY          CLEVELAND, OH 44130           Cleveland
# 9969         10015 VIENNA DR          CLEVELAND, OH 44130           Cleveland
# 9970          11795 GROSS DR              PARMA, OH 44130               Parma
# 9971       4071 E SPRAGUE RD        SEVEN HILLS, OH 44131         Seven Hills
# 9972        96 MEADOWLANE RD        SEVEN HILLS, OH 44131         Seven Hills
# 9973      1723 MEADOWLANE RD        SEVEN HILLS, OH 44131         Seven Hills
# 9974    7632 VALLEY VISTA RD       INDEPENDENCE, OH 44131        Independence
# 9975           7870 RIDGE RD              PARMA, OH 44129               Parma
# 9976      8275 TANGLEWOOD LN              PARMA, OH 44129               Parma
# 9977      8375 TANGLEWOOD LN              PARMA, OH 44129               Parma
# 9978      7975 OAKBROOK OVAL              PARMA, OH 44129               Parma
# 9979          7901 WALTON RD          CLEVELAND, OH 44146           Cleveland
# 9980        17732 RAULAND DR          CLEVELAND, OH 44146           Cleveland
# 9981           4714 MASON RD           SANDUSKY, OH 44870            Sandusky
# 9982  7522 ROYAL PORTRUSH DR              SOLON, OH 44139               Solon
# 9983        7475 CAPILANO DR              SOLON, OH 44139               Solon
#
#                                         address/oneLine  address/postal1  \
# 0                 11024 DOVER RD, APPLE CREEK, OH 44606            44606
# 1               7651 BUSS RD # A, APPLE CREEK, OH 44606            44606
# 2                  LINCOLN WAY E, APPLE CREEK, OH 44606            44606
# 3                    CHIPPEWA RD, APPLE CREEK, OH 44606            44606
# 4         3610 FREDERICKSBURG RD, APPLE CREEK, OH 44606            44606
# 5               12733 EMERSON RD, APPLE CREEK, OH 44606            44606
# 6            4353 S HONEYTOWN RD, APPLE CREEK, OH 44606            44606
# 7              114 SPRING RUN DR, APPLE CREEK, OH 44606            44606
# 8                    208 MILL ST, APPLE CREEK, OH 44606            44606
# 9                  732 W MAIN ST, APPLE CREEK, OH 44606            44606
# 10                 5082 DOVER RD, APPLE CREEK, OH 44606            44606
# 11              10536 HACKETT RD, APPLE CREEK, OH 44606            44606
# 12               14950 HACKETT RD, APPLE CREEK,OH 44606            44606
# 13                2706 S CARR RD, APPLE CREEK, OH 44606            44606
# 14                   9103 ELY RD, APPLE CREEK, OH 44606            44606
# 15                10216 DOVER RD, APPLE CREEK, OH 44606            44606
# 16                10532 DOVER RD, APPLE CREEK, OH 44606            44606
# 17                  7562 BUSS RD, APPLE CREEK, OH 44606            44606
# 18                  7970 BUSS RD, APPLE CREEK, OH 44606            44606
# 19                5455 OBERLY DR, APPLE CREEK, OH 44606            44606
# 20               8575 EMERSON RD, APPLE CREEK, OH 44606            44606
# 21              10043 EMERSON RD, APPLE CREEK, OH 44606            44606
# 22                 31 SHANNON DR, APPLE CREEK, OH 44606            44606
# 23              12990 EMERSON RD, APPLE CREEK, OH 44606            44606
# 24                4767 S CARR RD, APPLE CREEK, OH 44606            44606
# 25            294 APPLE RIDGE DR, APPLE CREEK, OH 44606            44606
# 26             72 APPLE RIDGE DR, APPLE CREEK, OH 44606            44606
# 27                   49 MAPLE ST, APPLE CREEK, OH 44606            44606
# 28                97 DOGWOOD CIR, APPLE CREEK, OH 44606            44606
# 29                  5315 DOVER RD, APPLE CREEK,OH 44606            44606
# ...                                                 ...              ...
# 9954                 4550 W SPRAGUE RD, PARMA, OH 44134            44134
# 9955             2580 W SPRAGUE RD, CLEVELAND, OH 44134            44134
# 9956              4040 W SPRAGUE RD, CLEVELAND,OH 44134            44134
# 9957                 5280 ARLINGTON LN, PARMA, OH 44134            44134
# 9958                 5320 ARLINGTON LN, PARMA, OH 44134            44134
# 9959                6810 ARBOR CT # 25, PARMA, OH 44134            44134
# 9960                     6160 KELLEY LN, PARMA,OH 44134            44134
# 9961                    6000 KELLEY LN, PARMA, OH 44134            44134
# 9962                12100 W SPRAGUE RD, PARMA, OH 44130            44130
# 9963                      7881 NEIL DR, PARMA, OH 44130            44130
# 9964                  7871 E LINDEN LN, PARMA, OH 44130            44130
# 9965              13994 BYRON BLVD, CLEVELAND, OH 44130            44130
# 9966  13901 BENNINGTON BLVD, MIDDLEBURG HEIGHTS,OH 4...            44130
# 9967                  7794 E LINDEN LN, PARMA, OH 44130            44130
# 9968                7733 ALAN PKWY, CLEVELAND, OH 44130            44130
# 9969               10015 VIENNA DR, CLEVELAND, OH 44130            44130
# 9970                    11795 GROSS DR, PARMA, OH 44130            44130
# 9971           4071 E SPRAGUE RD, SEVEN HILLS, OH 44131            44131
# 9972            96 MEADOWLANE RD, SEVEN HILLS, OH 44131            44131
# 9973          1723 MEADOWLANE RD, SEVEN HILLS, OH 44131            44131
# 9974       7632 VALLEY VISTA RD, INDEPENDENCE, OH 44131            44131
# 9975                     7870 RIDGE RD, PARMA, OH 44129            44129
# 9976                8275 TANGLEWOOD LN, PARMA, OH 44129            44129
# 9977                8375 TANGLEWOOD LN, PARMA, OH 44129            44129
# 9978                7975 OAKBROOK OVAL, PARMA, OH 44129            44129
# 9979                7901 WALTON RD, CLEVELAND, OH 44146            44146
# 9980              17732 RAULAND DR, CLEVELAND, OH 44146            44146
# 9981                  4714 MASON RD, SANDUSKY, OH 44870            44870
# 9982            7522 ROYAL PORTRUSH DR, SOLON, OH 44139            44139
# 9983                  7475 CAPILANO DR, SOLON, OH 44139            44139
#
#       location/latitude  location/longitude  ...  vintage/lastModified  \
# 0             40.724398          -81.784024  ...            2018-01-27
# 1             40.726153          -81.836130  ...            2018-01-27
# 2             40.732470          -81.799850  ...            2018-01-27
# 3             40.732470          -81.799850  ...            2018-01-27
# 4             40.732470          -81.799850  ...            2018-01-27
# 5             40.741033          -81.760147  ...            2018-01-27
# 6             40.744233          -81.876709  ...            2018-01-27
# 7             40.743184          -81.826779  ...            2018-01-27
# 8             40.749435          -81.831509  ...            2018-01-27
# 9             40.755597          -81.845627  ...            2018-01-27
# 10            40.756949          -81.871391  ...            2018-01-27
# 11            40.755914          -81.789208  ...            2018-01-27
# 12            40.756040          -81.716854  ...            2018-01-27
# 13            40.762476          -81.794023  ...            2018-01-27
# 14            40.777612          -81.810553  ...            2018-09-28
# 15            40.724657          -81.784803  ...            2018-01-27
# 16            40.726262          -81.789608  ...            2018-01-27
# 17            40.726415          -81.838100  ...            2018-01-27
# 18            40.726451          -81.831125  ...            2018-01-27
# 19            40.734738          -81.808689  ...            2018-01-27
# 20            40.740831          -81.821461  ...            2018-01-27
# 21            40.740840          -81.811424  ...            2018-10-19
# 22            40.744258          -81.826051  ...            2018-01-27
# 23            40.741347          -81.748187  ...            2018-12-21
# 24            40.742296          -81.815009  ...            2018-01-27
# 25            40.746385          -81.826383  ...            2018-01-27
# 26            40.744693          -81.829369  ...            2018-01-27
# 27            40.749279          -81.834458  ...            2018-01-27
# 28            40.751543          -81.832278  ...            2018-07-23
# 29            40.749682          -81.852831  ...            2018-01-27
# ...                 ...                 ...  ...                   ...
# 9954          41.351039          -81.717089  ...            2018-01-27
# 9955          41.351067          -81.699814  ...            2018-01-27
# 9956          41.351863          -81.712457  ...            2018-01-27
# 9957          41.352619          -81.721594  ...            2018-01-27
# 9958          41.352925          -81.721983  ...            2018-08-10
# 9959          41.353355          -81.733005  ...            2018-01-27
# 9960          41.354120          -81.727560  ...            2018-06-15
# 9961          41.354438          -81.727256  ...            2018-01-27
# 9962          41.350851          -81.772630  ...            2018-01-27
# 9963          41.350936          -81.782849  ...            2018-01-27
# 9964          41.351470          -81.773672  ...            2018-01-27
# 9965          41.351918          -81.794422  ...            2018-01-27
# 9966          41.352722          -81.793365  ...            2019-01-18
# 9967          41.353945          -81.774003  ...            2018-01-27
# 9968          41.353832          -81.802670  ...            2018-01-27
# 9969          41.353857          -81.755240  ...            2018-01-27
# 9970          41.354313          -81.770508  ...            2018-01-27
# 9971          41.351207          -81.663514  ...            2018-01-27
# 9972          41.353758          -81.683581  ...            2018-08-17
# 9973          41.354092          -81.673700  ...            2018-01-27
# 9974          41.354443          -81.627546  ...            2019-05-03
# 9975          41.351960          -81.735725  ...            2018-01-27
# 9976          41.353322          -81.740118  ...            2018-01-27
# 9977          41.353313          -81.743012  ...            2018-01-27
# 9978          41.354209          -81.742249  ...            2018-01-27
# 9979          41.352096          -81.545840  ...            2018-01-27
# 9980          41.353018          -81.548363  ...            2018-01-27
# 9981          41.352564          -82.704732  ...            2018-05-29
# 9982          41.353538          -81.402656  ...            2018-01-27
# 9983          41.354390          -81.398723  ...            2018-01-27
#
#      vintage/pubDate sale/salesearchdate  sale/amount/saleamt  \
# 0         2018-03-01          2006-10-05                65000
# 1         2018-01-27          2010-04-16               200000
# 2         2018-03-01          2017-06-19               650000
# 3         2018-03-01          2016-08-02               142800
# 4         2018-03-01          2015-10-29               250000
# 5         2018-01-27          2017-11-21               130000
# 6         2018-03-01          2015-04-23               175000
# 7         2018-03-01          2017-10-26               164000
# 8         2018-03-01          2017-09-18               150000
# 9         2018-01-27          2005-11-15                23500
# 10        2018-01-27          2013-04-11               100000
# 11        2018-03-01          2008-09-09               258327
# 12        2018-03-01          2015-11-16               110500
# 13        2018-03-01          2012-10-16                18000
# 14        2018-09-28          2018-08-20                52200
# 15        2018-01-27          2006-03-16               126000
# 16        2018-03-01          2009-02-27                57000
# 17        2018-01-27          2008-09-15                85000
# 18        2018-01-27          2008-01-08                76245
# 19        2018-03-01          2007-11-01                35000
# 20        2018-01-27          2015-02-03               124000
# 21        2018-10-19          2018-08-15               163000
# 22        2018-03-01          2008-02-11                25000
# 23        2018-12-21          2018-11-05               170000
# 24        2018-03-01          2017-02-03               230000
# 25        2018-03-01          2013-08-13               114900
# 26        2018-03-01          2017-07-03               168000
# 27        2018-03-01          2012-09-06                50000
# 28        2018-07-23          2014-10-02                68000
# 29        2018-03-01          2017-05-24               200000
# ...              ...                 ...                  ...
# 9954      2018-01-27          2013-10-30                80000
# 9955      2018-03-01          2013-08-01                95000
# 9956      2018-01-27          2005-03-11               226500
# 9957      2018-01-27          2007-08-21               214621
# 9958      2018-08-10          2016-04-28               142500
# 9959      2018-03-01          2006-03-21               159500
# 9960      2018-06-15          2014-02-10               212000
# 9961      2018-01-27          2016-06-02               212000
# 9962      2018-01-27          2005-01-25               260000
# 9963      2018-01-27          2013-10-09               104765
# 9964      2018-01-27          2017-07-10               199000
# 9965      2018-01-27          2007-08-08               277200
# 9966      2019-01-25          2018-08-04               239800
# 9967      2018-01-27          2012-09-27                81000
# 9968      2018-01-27          2005-11-03               119100
# 9969      2018-01-27          2016-09-27               125000
# 9970      2018-01-27          2016-09-28               131500
# 9971      2018-01-27          2015-03-27               120000
# 9972      2018-08-17          2016-12-05               127000
# 9973      2018-01-27          2007-03-21               215000
# 9974      2019-05-03          2019-04-15               240000
# 9975      2018-01-27          2015-05-28               130000
# 9976      2018-01-27          2017-06-07               214000
# 9977      2018-01-27          2007-02-27               250000
# 9978      2018-01-27          2006-07-22               265000
# 9979      2018-03-01          2011-06-21               140000
# 9980      2018-01-27          2012-04-02               225000
# 9981      2018-05-29          2018-02-23               173000
# 9982      2018-03-01          2005-02-25               467000
# 9983      2018-01-27          2016-06-27               555000
#
#       sale/amount/salerecdate    sale/amount/saletranstype  \
# 0                  2006-10-05                       Resale
# 1                  2010-04-23                       Resale
# 2                  2017-06-20                       Resale
# 3                  2016-08-04                       Resale
# 4                  2015-10-30                       Resale
# 5                  2017-11-27                       Resale
# 6                  2015-05-20                       Resale
# 7                  2017-10-27                       Resale
# 8                  2017-09-20                       Resale
# 9                  2005-11-17  Construction Loan/Financing
# 10                 2013-04-12     REO (Transfer to Lender)
# 11                 2008-09-09                       Resale
# 12                 2015-11-18                       Resale
# 13                 2012-10-17                       Resale
# 14                 2018-08-21                       Resale
# 15                 2006-03-16                       Resale
# 16                 2009-02-27                       Resale
# 17                 2008-09-15                       Resale
# 18                 2008-01-08                       Resale
# 19                 2007-11-01                       Resale
# 20                 2015-02-04                       Resale
# 21                 2018-09-20                       Resale
# 22                 2015-11-17                       Resale
# 23                 2018-11-09                       Resale
# 24                 2017-02-06                       Resale
# 25                 2013-08-16                       Resale
# 26                 2017-07-07                       Resale
# 27                 2012-09-13                       Resale
# 28                 2014-11-07                       Resale
# 29                 2017-05-26                       Resale
# ...                       ...                          ...
# 9954               2013-10-31                       Resale
# 9955               2013-08-02                       Resale
# 9956               2005-03-11                       Resale
# 9957               2007-08-24             New Construction
# 9958               2016-04-29                       Resale
# 9959               2006-03-23                       Resale
# 9960               2014-02-12                       Resale
# 9961               2016-06-03                       Resale
# 9962               2005-01-25                       Resale
# 9963               2013-12-02                       Resale
# 9964               2017-07-12                       Resale
# 9965               2007-08-10                       Resale
# 9966               2018-08-06                       Resale
# 9967               2012-09-28                       Resale
# 9968               2005-11-03                       Resale
# 9969               2016-10-14                       Resale
# 9970               2016-09-29                       Resale
# 9971               2015-05-13                       Resale
# 9972               2016-12-05                       Resale
# 9973               2007-03-30                       Resale
# 9974               2019-04-15                       Resale
# 9975               2015-06-01                       Resale
# 9976               2017-06-09                       Resale
# 9977               2007-03-01                       Resale
# 9978               2006-07-24                       Resale
# 9979               2011-06-24                       Resale
# 9980               2012-04-03                       Resale
# 9981               2018-02-28                       Resale
# 9982               2005-02-25             New Construction
# 9983               2016-06-30             New Construction
#
#       sale/calculation/priceperbed sale/calculation/pricepersizeunit  \
# 0                            10833                                16
# 1                            22222                                36
# 2                                0                                 0
# 3                                0                                 0
# 4                                0                                 0
# 5                            43333                                99
# 6                            58333                                93
# 7                            54667                               133
# 8                            50000                                65
# 9                             7833                                18
# 10                           33333                                73
# 11                           86109                                87
# 12                           36833                                67
# 13                            6000                                14
# 14                           17400                                18
# 15                           42000                               111
# 16                           28500                                59
# 17                           28333                                55
# 18                           38123                                28
# 19                            7000                                12
# 20                           41333                                57
# 21                           23286                                53
# 22                               0                                 0
# 23                           42500                               119
# 24                           57500                               139
# 25                           38300                                92
# 26                           56000                               108
# 27                               0                                 0
# 28                           68000                                66
# 29                               0                                 0
# ...                            ...                               ...
# 9954                         20000                                39
# 9955                         31667                                85
# 9956                         56625                                94
# 9957                        107311                               135
# 9958                         47500                               103
# 9959                         79750                               111
# 9960                        106000                               116
# 9961                         70667                               110
# 9962                         86667                               126
# 9963                         34922                                52
# 9964                         66333                               122
# 9965                         69300                                95
# 9966                         59950                                86
# 9967                         27000                                55
# 9968                         39700                               112
# 9969                         41667                                68
# 9970                         43833                               113
# 9971                         24000                                50
# 9972                         42333                               113
# 9973                         53750                               158
# 9974                         80000                               145
# 9975                         43333                                88
# 9976                         53500                                98
# 9977                         83333                               108
# 9978                         66250                               101
# 9979                         46667                                85
# 9980                         75000                                71
# 9981                         57667                               122
# 9982                        116750                               114
# 9983                        138750                               149
#
#      sale/saleTransDate median_income
# 0                   NaN         56906
# 1             4/16/2010         56906
# 2             6/19/2017         56906
# 3              8/2/2016         56906
# 4            10/29/2015         56906
# 5            11/21/2017         56906
# 6             4/23/2015         56906
# 7            10/26/2017         56906
# 8             9/18/2017         56906
# 9            11/15/2005         56906
# 10            4/11/2013         56906
# 11                  NaN         56906
# 12           11/16/2015         56906
# 13           10/16/2012         56906
# 14            8/20/2018         56906
# 15                  NaN         56906
# 16                  NaN         56906
# 17                  NaN         56906
# 18                  NaN         56906
# 19                  NaN         56906
# 20             2/3/2015         56906
# 21            8/15/2018         56906
# 22            2/11/2008         56906
# 23            11/5/2018         56906
# 24             2/3/2017         56906
# 25            8/13/2013         56906
# 26             7/3/2017         56906
# 27             9/6/2012         56906
# 28            10/2/2014         56906
# 29            5/24/2017         56906
# ...                 ...           ...
# 9954         10/30/2013         51928
# 9955           8/1/2013         51928
# 9956                NaN         51928
# 9957          8/21/2007         51928
# 9958          4/28/2016         51928
# 9959          3/21/2006         51928
# 9960          2/10/2014         51928
# 9961           6/2/2016         51928
# 9962          1/25/2005         53059
# 9963          10/9/2013         53059
# 9964          7/10/2017         53059
# 9965           8/8/2007         53059
# 9966           8/4/2018         53059
# 9967          9/27/2012         53059
# 9968                NaN         53059
# 9969          9/27/2016         53059
# 9970          9/28/2016         53059
# 9971          3/27/2015         81962
# 9972          12/5/2016         81962
# 9973          3/21/2007         81962
# 9974          4/15/2019         81962
# 9975          5/28/2015         52863
# 9976           6/7/2017         52863
# 9977          2/27/2007         52863
# 9978          7/22/2006         52863
# 9979          6/21/2011         44097
# 9980           4/2/2012         44097
# 9981          2/23/2018         42980
# 9982                NaN         98849
# 9983          6/27/2016         98849
#
# [9984 rows x 27 columns]

# %%
map=df.loc[:,['address/line1', 'address/locality', 'address/countrySubd', 'address/postal1', "sale/amount/saleamt", 'sale/amount/salerecdate', 'location/latitude', 'location/longitude']]
maps=map.rename(columns={'address/line1': 'street_1', 'address/locality': 'city', 'address/countrySubd': 'state', 'address/postal1': 'zip', 'sale/amount/saleamt': 'sale_price', 'sale/amount/salerecdate': 'date', 'location/latitude': 'latitude', 'location/longitude':'longitude'}) 
map5=maps.dropna(how='any')

map5.to_csv('map5.csv')

# %%
plt.figure(figsize=(10,6))
plt.scatter(df2['location/longitude'],y=df2['location/latitude'],alpha=0.1)
plt.title("Distribution of households",size=16)
# Out:
# Text(0.5, 1.0, 'Distribution of households')

# %%
house=pd.read_csv('house.csv', dtype={'name': int, 'med/housing':int })
house1=house.drop(['geoid', 'B25077001, Error'], axis=1)
house2=house1.rename(columns={'name': 'address/postal1'})
houses=house2.iloc[1:]
houses2=houses.loc[houses["med/housing"] > 1, :]

# %%
dem=pd.read_csv('demo.csv', dtype={'1':float, 'total':int, 'address/postal1':int, '2':int, '3':int, '4':int})
dem2=dem.iloc[1:]
dem3=dem2.loc[:, ["address/postal1", "total", "1", "2", "3", "4"]]
dem3['1per']=(dem3['1']/dem3['total'])*100
dem3['2per']=(dem3['2']/dem3['total'])*100
dem3['4per']=(dem3['4']/dem3['total'])*100

# %%
pop=pd.read_csv('pop.csv', dtype={'population':float, 'address/postal1':int})
pop2=pop.iloc[1:]
pop3=pop2.loc[:, ["address/postal1", "population" ]]

# %%
edu=pd.read_csv('education.csv', dtype={'total':float, 'address/postal1':int, 'Bachelors':int, 'Masters':int, 'HighSchool':int, 'Associates':int, 'Professional':int, 'Doctorate':int})
edu2=edu.iloc[1:]
edu3=edu2.loc[:, ["address/postal1", "total", "Bachelors", "Masters", "HighSchool", "Associates", "Professional", "Doctorate"]]
edu3['bachper']=(edu3['Bachelors']/edu3['total'])*100
edu3['docper']=(edu3['Doctorate']/edu3['total'])*100
edu3['mastper']=(edu3['Masters']/edu3['total'])*100
edu3['HSper']=(edu3['HighSchool']/edu3['total'])*100

# %%
age=pd.read_csv('age.csv', dtype={'total':float, 'address/postal1':int})
age2=age.iloc[1:]
age3=age2.drop(['geoid', 'B01002000.5', 'B01002000.5, Error', 'B01002001, Error', 'male', 'female', 'B01002002, Error', 'B01002003, Error'], axis=1)

# %%
merge1=dem3.merge(pop3, how='inner', on='address/postal1' )
merge2=merge1.merge(edu3, how='outer', on='address/postal1')
merge3=merge2.merge(age3, how='inner', on='address/postal1')
merge3.head()
# Out:
#    address/postal1  total_x        1     2  3     4       1per       2per  \
# 0            16159     4824   4703.0    11  0    13  97.491708   0.228027
# 1            43001     2890   2782.0     0  0     0  96.262976   0.000000
# 2            43002     3238   3020.0    98  0    97  93.267449   3.026560
# 3            43003     2895   2836.0     0  0     2  97.962003   0.000000
# 4            43004    25768  17174.0  6538  0  1092  66.648556  25.372555
#
#        4per  population  ...  Masters  HighSchool  Associates  Professional  \
# 0  0.269486      4824.0  ...      237        1571         316             0
# 1  0.000000      2890.0  ...      162         659         134            28
# 2  2.995676      3238.0  ...      298         221         431           109
# 3  0.069085      2895.0  ...       72         835         165             8
# 4  4.237814     25768.0  ...     1765        2887        1355           409
#
#    Doctorate    bachper    docper    mastper      HSper  total
# 0          0  13.741110  0.000000   6.742532  44.694168   47.3
# 1          8  21.461657  0.411734   8.337622  33.916624   39.3
# 2         11  41.672426  0.380097  10.297167   7.636489   32.7
# 3          9  13.473787  0.440960   3.527683  40.911318   41.3
# 4        171  30.537597  0.995981  10.280156  16.815190   34.9
#
# [5 rows x 22 columns]

# %%
food_stamp=pd.read_csv('fs.csv', dtype={'PA/FS': int, 'NO_PA/FS':int, 'address/postal1':int})
fs=food_stamp.drop(['geoid', 'B19058001, Error', 'B19058002, Error', 'B19058003, Error'], axis=1)
fs['perc_fs']=(fs['PA/FS']/fs['B19058001'])*100
fs1=fs.drop(['B19058001'], axis=1)
fs2=fs1.iloc[1:]

# %%
med_inc2=pd.read_csv('medianincome.csv', dtype={'zipcode': int, 'median':int})
med_inc=med_inc2.rename(columns={'zipcode': 'address/postal1', 'median': 'median_income'})
income=med_inc.drop(['geoid', 'B19013001, Error'], axis=1)
income2 = income.iloc[1:]

# %%
df_res= df.loc[df["summary/propclass"] == "Single Family Residence / Townhouse", :]
b=df_res['address/postal1'].unique()
dataframe2=pd.DataFrame(b, columns=['zip'])

# %%
e=df_res['address/locality'].unique()
dataframe=pd.DataFrame(e, columns=['a'])
dataframe.to_csv("crime2.csv")

# %%
df_r=pd.read_csv('desc_df2.csv')

# %%
df_r['identifier/obPropId'].astype(str)
ids=df_r['identifier/obPropId'].tolist()

# %%
desc_df = df_res.sort_values("sale/amount/salerecdate", ascending=False)
desc_df2=desc_df.iloc[0:1000, :]
#desc_df2.to_csv('desc_df.csv')

# %%
desc_df3=desc_df2.loc[desc_df2["summary/yearbuilt"] > 1, :]

# %%
desc_df4=desc_df3.loc[desc_df3["sale/amount/saleamt"] > 5000, :]

# %%
desc_df5=desc_df4.loc[desc_df4['building/rooms/bathstotal'] > 0, :]

# %%
desc_df6=desc_df5.merge(income2, how='inner', on= 'address/postal1')

# %%
desc_df7=desc_df6.loc[desc_df6["median_income"] > 1, :]

# %%
desc_df8=desc_df7.loc[desc_df7["sale/amount/saleamt"] < 700000, :]

# %%
desc_df9=desc_df8.merge(fs2, how='inner', on='address/postal1')

# %%
desc_df10=desc_df9.merge(houses2, how='inner', on='address/postal1')

# %%
desc_df11=desc_df10.merge(merge3, how='inner', on='address/postal1')

# %%
desc_df12=desc_df11.loc[desc_df11["population"] > 1, :]

# %%
desc_df13=desc_df12.loc[desc_df12["location/distance"] < 45, :]

# %%
desc_df14=desc_df13.loc[desc_df13["LotSizeAcres"] > 0.0000, :]

# %%
desc_df15=desc_df14.loc[desc_df14['building/rooms/bathstotal'] < 7, :]

# %%
desc_df16=desc_df15.loc[desc_df15['LotSizeAcres'] < 1 , :]

# %%
desc_df17=desc_df16.loc[desc_df16['med/housing'] < 400000 , :]

# %%
desc_df18=desc_df17.loc[desc_df17["location/distance"] > 5, :]

# %%
ML_df=desc_df18.loc[:, ["LotSizeAcres", "med/housing", "median_income", "HSper", "bachper", "total", "perc_fs", "summary/yearbuilt", "mastper", "building/rooms/bathstotal", "population", "building/rooms/beds", "sale/amount/saleamt"]]
ML_df.to_csv('ML.csv')
ML_df['difference_house']=ML_df['sale/amount/saleamt']-ML_df['med/housing']
ML_df['year_b2']=2019-ML_df['summary/yearbuilt']
ML_df.describe()
# Out:
#        LotSizeAcres    med/housing  median_income       HSper     bachper  \
# count    664.000000     664.000000     664.000000  664.000000  664.000000
# mean       0.301933  134825.903614   55820.959337   30.116346   17.985778
# std        0.208838   54639.806903   19216.100679    6.846992    8.020806
# min        0.033100   51200.000000   19026.000000    9.739401    2.977083
# 25%        0.137700   77600.000000   40316.000000   24.348681   11.921131
# 50%        0.241700  142400.000000   53148.000000   31.471718   16.541762
# 75%        0.432975  170400.000000   69094.000000   34.861842   25.240597
# max        0.990000  316600.000000  120825.000000   46.625259   38.790773
#
#             total     perc_fs  summary/yearbuilt     mastper  \
# count  664.000000  664.000000         664.000000  664.000000
# mean    40.866867   15.160673        1959.009036    7.137124
# std      4.557220   11.092863          30.909686    4.219654
# min     21.000000    0.530504        1860.000000    0.000000
# 25%     38.300000    6.870670        1934.500000    3.596701
# 50%     41.800000   11.296426        1957.000000    6.614815
# 75%     44.300000   25.014798        1983.250000    9.758846
# max     52.500000   53.423423        2018.000000   21.158603
#
#        building/rooms/bathstotal    population  building/rooms/beds  \
# count                 664.000000    664.000000           664.000000
# mean                    1.950301  24983.355422             3.118976
# std                     0.938019  12527.806308             0.715694
# min                     1.000000    865.000000             1.000000
# 25%                     1.000000  17732.000000             3.000000
# 50%                     2.000000  22586.000000             3.000000
# 75%                     3.000000  31074.000000             4.000000
# max                     5.000000  63572.000000             6.000000
#
#        sale/amount/saleamt  difference_house     year_b2
# count           664.000000        664.000000  664.000000
# mean         142787.265060       7961.361446   59.990964
# std          104339.766606      82072.699333   30.909686
# min            7000.000000    -294500.000000    1.000000
# 25%           60000.000000     -39500.000000   35.750000
# 50%          125000.000000      -6900.000000   62.000000
# 75%          197125.000000      41943.750000   84.500000
# max          570000.000000     359000.000000  159.000000

# %%
corr_matrix=ML_df.corr()
corr_matrix['sale/amount/saleamt'].sort_values(ascending=False)
# Out:
# sale/amount/saleamt          1.000000
# difference_house             0.854633
# building/rooms/bathstotal    0.692130
# med/housing                  0.625876
# summary/yearbuilt            0.614102
# median_income                0.609474
# mastper                      0.598833
# bachper                      0.586867
# LotSizeAcres                 0.419465
# building/rooms/beds          0.418329
# total                        0.358182
# population                   0.170047
# HSper                       -0.491112
# perc_fs                     -0.566272
# year_b2                     -0.614102
# Name: sale/amount/saleamt, dtype: float64

# %%
import seaborn as sns
num_features=["LotSizeAcres", "med/housing", "median_income", "HSper", "bachper", "perc_fs", "summary/yearbuilt", "building/rooms/bathstotal", "building/rooms/beds", "sale/amount/saleamt"]
for i in num_features:
    fig, ax = plt.subplots()
    fig.set_size_inches(12,6)
    #plt.xlim(-10,10)
    sns.boxplot(x=i,data=ML_df,ax=ax)

# %%
ML_df1=ML_df.copy()
skewness=[]
for i in num_features:
    skewness.append(ML_df1[i].skew())
pd.DataFrame(data=skewness,index=num_features,columns=['skewness']).sort_values(by='skewness',ascending=False)
# Out:
#                            skewness
# LotSizeAcres               1.270203
# perc_fs                    1.090972
# sale/amount/saleamt        1.090372
# building/rooms/bathstotal  0.648988
# med/housing                0.519004
# median_income              0.477764
# bachper                    0.300328
# building/rooms/beds        0.192593
# summary/yearbuilt         -0.062838
# HSper                     -0.341459

# %%
X = ML_df[["LotSizeAcres", "med/housing", "median_income", "HSper", "mastper", "bachper", "perc_fs", "summary/yearbuilt", "building/rooms/bathstotal", "building/rooms/beds"]]
y = ML_df["sale/amount/saleamt"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (664, 10) (664, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
# Out:
# C:\Users\emhar\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int32, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\emhar\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
# Out:
# C:\Users\emhar\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: Data with input dtype int32, int64, float64 were all converted to float64 by StandardScaler.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\emhar\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype int32, int64, float64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.
# C:\Users\emhar\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\emhar\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

model.fit(X_train_scaled, y_train_scaled)
training_score = model.score(X_train_scaled, y_train_scaled)
testing_score = model.score(X_test_scaled, y_test_scaled)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.6596347387074498
# Testing Score: 0.6073727830542146

# %%
pickle.dump(model, open('model.pkl','wb'))

# %%
# LASSO model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Lasso

### BEGIN SOLUTION
lasso = Lasso(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = lasso.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = lasso.score(X_test_scaled, y_test_scaled)
### END SOLUTION
training_score = model.score(X_train_scaled, y_train_scaled)


print(f"Training Score: {training_score}")

print(f"MSE: {MSE}, testing: {r2}")
# Out:
# Training Score: 0.6174627785670378
# MSE: 0.3981839436220405, testing: 0.6151031358505823

# %%
predictions = model.predict(X_test_scaled)
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()

# %%
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.47126807929889997, R2: 0.6187467711302158

# %%
from sklearn import neighbors
from sklearn.model_selection import GridSearchCV
params = {'n_neighbors':[2,3,4,5,6,7,8,9]}

knn = neighbors.KNeighborsRegressor()

model = GridSearchCV(knn, params, cv=5)
model.fit(X_train_scaled ,y_train_scaled)
model.best_params_
# Out:
# {'n_neighbors': 9}

# %%
from sklearn.neighbors import KNeighborsRegressor

neigh = KNeighborsRegressor(n_neighbors=9)
neigh.fit(X_train_scaled, y_train_scaled)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=9, p=2,
#           weights='uniform')

# %%
training_score = neigh.score(X_train_scaled, y_train_scaled)
testing_score = neigh.score(X_test_scaled, y_test_scaled)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.699865705488885
# Testing Score: 0.6120401712587836

# %%
MSE2 = mean_squared_error(y_test_scaled, neigh.predict(X_test_scaled))
print(MSE2)
# Out:
# 0.47955812434168066

# %%
from sklearn.ensemble import RandomForestRegressor 
  
 # create regressor object 
regressor = RandomForestRegressor(n_estimators = 700, min_samples_split= 5, min_samples_leaf= 2, max_depth=20, random_state=6) 
  
# fit the regressor with x and y data 
regressor.fit(X_train_scaled, y_train_scaled.ravel())
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=20,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=2, min_samples_split=5,
#            min_weight_fraction_leaf=0.0, n_estimators=700, n_jobs=None,
#            oob_score=False, random_state=6, verbose=0, warm_start=False)

# %%
training_score = regressor.score(X_train_scaled, y_train_scaled)
testing_score = regressor.score(X_test_scaled, y_test_scaled)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.9088834647768642
# Testing Score: 0.6870719011577192

# %%
data = X = ML_df[["LotSizeAcres", "med/housing", "perc_fs", "median_income", "bachper", "summary/yearbuilt", "building/rooms/bathstotal", "building/rooms/beds"]]

print(X.shape, y.shape)
feature_names = data.columns
sorted(zip(regressor.feature_importances_, feature_names), reverse=True)
# Out:
# (664, 8) (664, 1)
# [(0.1498586466033421, 'building/rooms/beds'),
#  (0.08938333173586444, 'bachper'),
#  (0.07188409970445378, 'med/housing'),
#  (0.06468584024021283, 'LotSizeAcres'),
#  (0.03570446434210737, 'summary/yearbuilt'),
#  (0.03535942094224198, 'perc_fs'),
#  (0.03456834982380668, 'median_income'),
#  (0.03073654955162739, 'building/rooms/bathstotal')]

# %%
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 50, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
#rf = RandomForestRegressor()
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
#rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
# Fit the random search model
#rf_random.fit(X_train_scaled, y_train_scaled.ravel())

# %%
#rf_random.best_params_

# %%
#explore api options
import http.client 

conn = http.client.HTTPSConnection("api.gateway.attomdata.com") 

headers = { 
    'accept': "application/json", 
    'apikey': "487ac4986deb86031b6d88f9505dfdc6", 
} 

ids="18471319108031"
conn.request("GET", "/propertyapi/v1.0.0/property/detail?id="+ ids, headers=headers) 

res = conn.getresponse() 
data = res.read() 

data1=data.decode("utf-8")
print(data1)
# Out:
# {"status":{"version":"1.0.0","code":0,"msg":"SuccessWithResult","total":1,"page":1,"pagesize":10},"property":[{"identifier":{"obPropId":18471319108031,"fips":"08031","apn":"0219204018000","apnOrig":"219204018000","attomId":184713191},"lot":{"depth":0,"frontage":0,"lotnum":"31","lotsize1":0.1077,"lotsize2":4690,"pooltype":"NONE"},"area":{"blockNum":"36","countrysecsubd":"Denver County","countyuse1":"113","muncode":"DE","munname":"DENVER","srvyRange":"68W","srvySection":"19","srvyTownship":"03S","subdname":"BERKELEY","subdtractnum":"0","taxcodearea":"0"},"address":{"country":"US","countrySubd":"CO","line1":"4529 WINONA CT","line2":"DENVER, CO 80212","locality":"Denver","matchCode":"ExaStr","oneLine":"4529 WINONA CT, DENVER, CO 80212","postal1":"80212","postal2":"2512","postal3":"C037"},"location":{"accuracy":"Street","elevation":0.0,"latitude":"39.778904","longitude":"-105.047624","distance":0.0,"geoid":"CO08031, CS0891007, DB0803360, MT30001324, ND0000119198, ND0000539537, PL0820000, SB0000076114, SB0000076155, SB0000076161, SB0000135819, ZI80212"},"summary":{"absenteeInd":"OWNER OCCUPIED","propclass":"Single Family Residence / Townhouse","propsubtype":"RESIDENTIAL","proptype":"SFR","yearbuilt":1900,"propLandUse":"SFR","propIndicator":"10","legal1":"BERKELEY B36 L31 & S/2 OF L32 EXC REAR 8FT TO CITY"},"utilities":{"heatingtype":"FORCED AIR"},"building":{"size":{"bldgsize":1414,"grosssize":1414,"grosssizeadjusted":934,"groundfloorsize":934,"livingsize":934,"sizeInd":"LIVING SQFT ","universalsize":934},"rooms":{"bathfixtures":0,"baths1qtr":0,"baths3qtr":0,"bathscalc":1.0,"bathsfull":1,"bathshalf":0,"bathstotal":1.0,"beds":2,"roomsTotal":5},"interior":{"bsmtsize":480,"bsmttype":"UNFINISHED","fplccount":1,"fplcind":"Y","fplctype":"YES"},"construction":{"condition":"AVERAGE","wallType":"BRICK"},"parking":{"garagetype":"DETACHED GARAGE","prkgSize":240,"prkgSpaces":"0","prkgType":"GARAGE DETACHED"},"summary":{"bldgsNum":0,"bldgType":"TYPE UNKNOWN","imprType":"RESIDENTIAL","levels":1,"mobileHomeInd":" ","quality":"EXCELLENT","storyDesc":"TYPE UNKNOWN","unitsCount":"1","yearbuilteffective":0}},"vintage":{"lastModified":"2019-5-22","pubDate":"2019-5-23"}}]}

# %%
import numpy
import pandas
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# define base model
def baseline_model():
    #create model
    model = Sequential()
    model.add(Dense(11, input_dim=11, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal'))
# Compile model
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
    return model

seed = 7
numpy.random.seed(seed)
estimator = KerasRegressor(build_fn=baseline_model, epochs=100, batch_size=5, verbose=2)

# %%
kfold = KFold(n_splits=10, random_state=seed)
results = cross_val_score(estimator, X_train_scaled, y_train_scaled, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Train on 449 samples
# Epoch 1/100
# 449/449 - 0s - loss: 0.8547 - accuracy: 0.0000e+00
# Epoch 2/100
# 449/449 - 0s - loss: 0.5391 - accuracy: 0.0000e+00
# Epoch 3/100
# 449/449 - 0s - loss: 0.4400 - accuracy: 0.0000e+00
# Epoch 4/100
# 449/449 - 0s - loss: 0.3988 - accuracy: 0.0000e+00
# Epoch 5/100
# 449/449 - 0s - loss: 0.3744 - accuracy: 0.0000e+00
# Epoch 6/100
# 449/449 - 0s - loss: 0.3543 - accuracy: 0.0000e+00
# Epoch 7/100
# 449/449 - 0s - loss: 0.3463 - accuracy: 0.0000e+00
# Epoch 8/100
# 449/449 - 0s - loss: 0.3386 - accuracy: 0.0000e+00
# Epoch 9/100
# 449/449 - 0s - loss: 0.3355 - accuracy: 0.0000e+00
# Epoch 10/100
# 449/449 - 0s - loss: 0.3287 - accuracy: 0.0000e+00
# Epoch 11/100
# 449/449 - 0s - loss: 0.3279 - accuracy: 0.0000e+00
# Epoch 12/100
# 449/449 - 0s - loss: 0.3232 - accuracy: 0.0000e+00
# Epoch 13/100
# 449/449 - 0s - loss: 0.3212 - accuracy: 0.0000e+00
# Epoch 14/100
# 449/449 - 0s - loss: 0.3188 - accuracy: 0.0000e+00
# Epoch 15/100
# 449/449 - 0s - loss: 0.3146 - accuracy: 0.0000e+00
# Epoch 16/100
# 449/449 - 0s - loss: 0.3156 - accuracy: 0.0000e+00
# Epoch 17/100
# 449/449 - 0s - loss: 0.3112 - accuracy: 0.0000e+00
# Epoch 18/100
# 449/449 - 0s - loss: 0.3098 - accuracy: 0.0000e+00
# Epoch 19/100
# 449/449 - 0s - loss: 0.3080 - accuracy: 0.0000e+00
# Epoch 20/100
# 449/449 - 0s - loss: 0.3069 - accuracy: 0.0000e+00
# Epoch 21/100
# 449/449 - 0s - loss: 0.3063 - accuracy: 0.0000e+00
# Epoch 22/100
# 449/449 - 0s - loss: 0.3023 - accuracy: 0.0000e+00
# Epoch 23/100
# 449/449 - 0s - loss: 0.3022 - accuracy: 0.0000e+00
# Epoch 24/100
# 449/449 - 0s - loss: 0.2999 - accuracy: 0.0000e+00
# Epoch 25/100
# 449/449 - 0s - loss: 0.2995 - accuracy: 0.0000e+00
# Epoch 26/100
# 449/449 - 0s - loss: 0.2989 - accuracy: 0.0000e+00
# Epoch 27/100
# 449/449 - 0s - loss: 0.2979 - accuracy: 0.0000e+00
# Epoch 28/100
# 449/449 - 0s - loss: 0.2966 - accuracy: 0.0000e+00
# Epoch 29/100
# 449/449 - 0s - loss: 0.2975 - accuracy: 0.0000e+00
# Epoch 30/100
# 449/449 - 0s - loss: 0.2961 - accuracy: 0.0000e+00
# Epoch 31/100
# 449/449 - 0s - loss: 0.2922 - accuracy: 0.0000e+00
# Epoch 32/100
# 449/449 - 0s - loss: 0.2920 - accuracy: 0.0000e+00
# Epoch 33/100
# 449/449 - 0s - loss: 0.2945 - accuracy: 0.0000e+00
# Epoch 34/100
# 449/449 - 0s - loss: 0.2933 - accuracy: 0.0000e+00
# Epoch 35/100
# 449/449 - 0s - loss: 0.2900 - accuracy: 0.0000e+00
# Epoch 36/100
# 449/449 - 0s - loss: 0.2904 - accuracy: 0.0000e+00
# Epoch 37/100
# 449/449 - 0s - loss: 0.2874 - accuracy: 0.0000e+00
# Epoch 38/100
# 449/449 - 0s - loss: 0.2882 - accuracy: 0.0000e+00
# Epoch 39/100
# 449/449 - 0s - loss: 0.2865 - accuracy: 0.0000e+00
# Epoch 40/100
# 449/449 - 0s - loss: 0.2867 - accuracy: 0.0000e+00
# Epoch 41/100
# 449/449 - 0s - loss: 0.2854 - accuracy: 0.0000e+00
# Epoch 42/100
# 449/449 - 0s - loss: 0.2844 - accuracy: 0.0000e+00
# Epoch 43/100
# 449/449 - 0s - loss: 0.2841 - accuracy: 0.0000e+00
# Epoch 44/100
# 449/449 - 0s - loss: 0.2832 - accuracy: 0.0000e+00
# Epoch 45/100
# 449/449 - 0s - loss: 0.2835 - accuracy: 0.0000e+00
# Epoch 46/100
# 449/449 - 0s - loss: 0.2820 - accuracy: 0.0000e+00
# Epoch 47/100
# 449/449 - 0s - loss: 0.2840 - accuracy: 0.0000e+00
# Epoch 48/100
# 449/449 - 0s - loss: 0.2822 - accuracy: 0.0000e+00
# Epoch 49/100
# 449/449 - 0s - loss: 0.2817 - accuracy: 0.0000e+00
# Epoch 50/100
# 449/449 - 0s - loss: 0.2805 - accuracy: 0.0000e+00
# Epoch 51/100
# 449/449 - 0s - loss: 0.2791 - accuracy: 0.0000e+00
# Epoch 52/100
# 449/449 - 0s - loss: 0.2818 - accuracy: 0.0000e+00
# Epoch 53/100
# 449/449 - 0s - loss: 0.2789 - accuracy: 0.0000e+00
# Epoch 54/100
# 449/449 - 0s - loss: 0.2782 - accuracy: 0.0000e+00
# Epoch 55/100
# 449/449 - 0s - loss: 0.2770 - accuracy: 0.0000e+00
# Epoch 56/100
# 449/449 - 0s - loss: 0.2783 - accuracy: 0.0000e+00
# Epoch 57/100
# 449/449 - 0s - loss: 0.2745 - accuracy: 0.0000e+00
# Epoch 58/100
# 449/449 - 0s - loss: 0.2765 - accuracy: 0.0000e+00
# Epoch 59/100
# 449/449 - 0s - loss: 0.2766 - accuracy: 0.0000e+00
# Epoch 60/100
# 449/449 - 0s - loss: 0.2758 - accuracy: 0.0000e+00
# Epoch 61/100
# 449/449 - 0s - loss: 0.2732 - accuracy: 0.0000e+00
# Epoch 62/100
# 449/449 - 0s - loss: 0.2748 - accuracy: 0.0000e+00
# Epoch 63/100
# 449/449 - 0s - loss: 0.2760 - accuracy: 0.0000e+00
# Epoch 64/100
# 449/449 - 0s - loss: 0.2731 - accuracy: 0.0000e+00
# Epoch 65/100
# 449/449 - 0s - loss: 0.2733 - accuracy: 0.0000e+00
# Epoch 66/100
# 449/449 - 0s - loss: 0.2726 - accuracy: 0.0000e+00
# Epoch 67/100
# 449/449 - 0s - loss: 0.2728 - accuracy: 0.0000e+00
# Epoch 68/100
# 449/449 - 0s - loss: 0.2721 - accuracy: 0.0000e+00
# Epoch 69/100
# 449/449 - 0s - loss: 0.2718 - accuracy: 0.0000e+00
# Epoch 70/100
# 449/449 - 0s - loss: 0.2730 - accuracy: 0.0000e+00
# Epoch 71/100
# 449/449 - 0s - loss: 0.2725 - accuracy: 0.0000e+00
# Epoch 72/100
# 449/449 - 0s - loss: 0.2701 - accuracy: 0.0000e+00
# Epoch 73/100
# 449/449 - 0s - loss: 0.2708 - accuracy: 0.0000e+00
# Epoch 74/100
# 449/449 - 0s - loss: 0.2707 - accuracy: 0.0000e+00
# Epoch 75/100
# 449/449 - 0s - loss: 0.2709 - accuracy: 0.0000e+00
# Epoch 76/100
# 449/449 - 0s - loss: 0.2708 - accuracy: 0.0000e+00
# Epoch 77/100
# 449/449 - 0s - loss: 0.2700 - accuracy: 0.0000e+00
# Epoch 78/100
# 449/449 - 0s - loss: 0.2721 - accuracy: 0.0000e+00
# Epoch 79/100
# 449/449 - 0s - loss: 0.2697 - accuracy: 0.0000e+00
# Epoch 80/100
# 449/449 - 0s - loss: 0.2688 - accuracy: 0.0000e+00
# Epoch 81/100
# 449/449 - 0s - loss: 0.2697 - accuracy: 0.0000e+00
# Epoch 82/100
# 449/449 - 0s - loss: 0.2675 - accuracy: 0.0000e+00
# Epoch 83/100
# 449/449 - 0s - loss: 0.2680 - accuracy: 0.0000e+00
# Epoch 84/100
# 449/449 - 0s - loss: 0.2677 - accuracy: 0.0000e+00
# Epoch 85/100
# 449/449 - 0s - loss: 0.2681 - accuracy: 0.0000e+00
# Epoch 86/100
# 449/449 - 0s - loss: 0.2681 - accuracy: 0.0000e+00
# Epoch 87/100
# 449/449 - 0s - loss: 0.2682 - accuracy: 0.0000e+00
# Epoch 88/100
# 449/449 - 0s - loss: 0.2670 - accuracy: 0.0000e+00
# Epoch 89/100
# 449/449 - 0s - loss: 0.2661 - accuracy: 0.0000e+00
# Epoch 90/100
# 449/449 - 0s - loss: 0.2689 - accuracy: 0.0000e+00
# Epoch 91/100
# 449/449 - 0s - loss: 0.2679 - accuracy: 0.0000e+00
# Epoch 92/100
# 449/449 - 0s - loss: 0.2662 - accuracy: 0.0000e+00
# Epoch 93/100
# 449/449 - 0s - loss: 0.2665 - accuracy: 0.0000e+00
# Epoch 94/100
# 449/449 - 0s - loss: 0.2670 - accuracy: 0.0000e+00
# Epoch 95/100
# 449/449 - 0s - loss: 0.2655 - accuracy: 0.0000e+00
# Epoch 96/100
# 449/449 - 0s - loss: 0.2667 - accuracy: 0.0000e+00
# Epoch 97/100
# 449/449 - 0s - loss: 0.2645 - accuracy: 0.0000e+00
# Epoch 98/100
# 449/449 - 0s - loss: 0.2672 - accuracy: 0.0000e+00
# Epoch 99/100
# 449/449 - 0s - loss: 0.2668 - accuracy: 0.0000e+00
# Epoch 100/100
# 449/449 - 0s - loss: 0.2636 - accuracy: 0.0000e+00
# 50/50 - 0s - loss: 0.2170 - accuracy: 0.0000e+00
# Train on 449 samples
# Epoch 1/100
# 449/449 - 0s - loss: 0.8761 - accuracy: 0.0000e+00
# Epoch 2/100
# 449/449 - 0s - loss: 0.5702 - accuracy: 0.0000e+00
# Epoch 3/100
# 449/449 - 0s - loss: 0.4513 - accuracy: 0.0000e+00
# Epoch 4/100
# 449/449 - 0s - loss: 0.4012 - accuracy: 0.0000e+00
# Epoch 5/100
# 449/449 - 0s - loss: 0.3687 - accuracy: 0.0000e+00
# Epoch 6/100
# 449/449 - 0s - loss: 0.3484 - accuracy: 0.0000e+00
# Epoch 7/100
# 449/449 - 0s - loss: 0.3360 - accuracy: 0.0000e+00
# Epoch 8/100
# 449/449 - 0s - loss: 0.3270 - accuracy: 0.0000e+00
# Epoch 9/100
# 449/449 - 0s - loss: 0.3230 - accuracy: 0.0000e+00
# Epoch 10/100
# 449/449 - 0s - loss: 0.3178 - accuracy: 0.0000e+00
# Epoch 11/100
# 449/449 - 0s - loss: 0.3126 - accuracy: 0.0000e+00
# Epoch 12/100
# 449/449 - 0s - loss: 0.3118 - accuracy: 0.0000e+00
# Epoch 13/100
# 449/449 - 0s - loss: 0.3096 - accuracy: 0.0000e+00
# Epoch 14/100
# 449/449 - 0s - loss: 0.3062 - accuracy: 0.0000e+00
# Epoch 15/100
# 449/449 - 0s - loss: 0.3040 - accuracy: 0.0000e+00
# Epoch 16/100
# 449/449 - 0s - loss: 0.3027 - accuracy: 0.0000e+00
# Epoch 17/100
# 449/449 - 0s - loss: 0.3005 - accuracy: 0.0000e+00
# Epoch 18/100
# 449/449 - 0s - loss: 0.2970 - accuracy: 0.0000e+00
# Epoch 19/100
# 449/449 - 0s - loss: 0.2965 - accuracy: 0.0000e+00
# Epoch 20/100
# 449/449 - 0s - loss: 0.2939 - accuracy: 0.0000e+00
# Epoch 21/100
# 449/449 - 0s - loss: 0.2919 - accuracy: 0.0000e+00
# Epoch 22/100
# 449/449 - 0s - loss: 0.2923 - accuracy: 0.0000e+00
# Epoch 23/100
# 449/449 - 0s - loss: 0.2885 - accuracy: 0.0000e+00
# Epoch 24/100
# 449/449 - 0s - loss: 0.2866 - accuracy: 0.0000e+00
# Epoch 25/100
# 449/449 - 0s - loss: 0.2894 - accuracy: 0.0000e+00
# Epoch 26/100
# 449/449 - 0s - loss: 0.2840 - accuracy: 0.0000e+00
# Epoch 27/100
# 449/449 - 0s - loss: 0.2837 - accuracy: 0.0000e+00
# Epoch 28/100
# 449/449 - 0s - loss: 0.2825 - accuracy: 0.0000e+00
# Epoch 29/100
# 449/449 - 0s - loss: 0.2815 - accuracy: 0.0000e+00
# Epoch 30/100
# 449/449 - 0s - loss: 0.2812 - accuracy: 0.0000e+00
# Epoch 31/100
# 449/449 - 0s - loss: 0.2779 - accuracy: 0.0000e+00
# Epoch 32/100
# 449/449 - 0s - loss: 0.2765 - accuracy: 0.0000e+00
# Epoch 33/100
# 449/449 - 0s - loss: 0.2748 - accuracy: 0.0000e+00
# Epoch 34/100
# 449/449 - 0s - loss: 0.2755 - accuracy: 0.0000e+00
# Epoch 35/100
# 449/449 - 0s - loss: 0.2718 - accuracy: 0.0000e+00
# Epoch 36/100
# 449/449 - 0s - loss: 0.2705 - accuracy: 0.0000e+00
# Epoch 37/100
# 449/449 - 0s - loss: 0.2735 - accuracy: 0.0000e+00
# Epoch 38/100
# 449/449 - 0s - loss: 0.2683 - accuracy: 0.0000e+00
# Epoch 39/100
# 449/449 - 0s - loss: 0.2678 - accuracy: 0.0000e+00
# Epoch 40/100
# 449/449 - 0s - loss: 0.2663 - accuracy: 0.0000e+00
# Epoch 41/100
# 449/449 - 0s - loss: 0.2643 - accuracy: 0.0000e+00
# Epoch 42/100
# 449/449 - 0s - loss: 0.2637 - accuracy: 0.0000e+00
# Epoch 43/100
# 449/449 - 0s - loss: 0.2638 - accuracy: 0.0000e+00
# Epoch 44/100
# 449/449 - 0s - loss: 0.2637 - accuracy: 0.0000e+00
# Epoch 45/100
# 449/449 - 0s - loss: 0.2615 - accuracy: 0.0000e+00
# Epoch 46/100
# 449/449 - 0s - loss: 0.2598 - accuracy: 0.0000e+00
# Epoch 47/100
# 449/449 - 0s - loss: 0.2593 - accuracy: 0.0000e+00
# Epoch 48/100
# 449/449 - 0s - loss: 0.2577 - accuracy: 0.0000e+00
# Epoch 49/100
# 449/449 - 0s - loss: 0.2591 - accuracy: 0.0000e+00
# Epoch 50/100
# 449/449 - 0s - loss: 0.2570 - accuracy: 0.0000e+00
# Epoch 51/100
# 449/449 - 0s - loss: 0.2556 - accuracy: 0.0000e+00
# Epoch 52/100
# 449/449 - 0s - loss: 0.2547 - accuracy: 0.0000e+00
# Epoch 53/100
# 449/449 - 0s - loss: 0.2529 - accuracy: 0.0000e+00
# Epoch 54/100
# 449/449 - 0s - loss: 0.2553 - accuracy: 0.0000e+00
# Epoch 55/100
# 449/449 - 0s - loss: 0.2553 - accuracy: 0.0000e+00
# Epoch 56/100
# 449/449 - 0s - loss: 0.2538 - accuracy: 0.0000e+00
# Epoch 57/100
# 449/449 - 0s - loss: 0.2517 - accuracy: 0.0000e+00
# Epoch 58/100
# 449/449 - 0s - loss: 0.2524 - accuracy: 0.0000e+00
# Epoch 59/100
# 449/449 - 0s - loss: 0.2517 - accuracy: 0.0000e+00
# Epoch 60/100
# 449/449 - 0s - loss: 0.2498 - accuracy: 0.0000e+00
# Epoch 61/100
# 449/449 - 0s - loss: 0.2518 - accuracy: 0.0000e+00
# Epoch 62/100
# 449/449 - 0s - loss: 0.2514 - accuracy: 0.0000e+00
# Epoch 63/100
# 449/449 - 0s - loss: 0.2468 - accuracy: 0.0000e+00
# Epoch 64/100
# 449/449 - 0s - loss: 0.2503 - accuracy: 0.0000e+00
# Epoch 65/100
# 449/449 - 0s - loss: 0.2495 - accuracy: 0.0000e+00
# Epoch 66/100
# 449/449 - 0s - loss: 0.2492 - accuracy: 0.0000e+00
# Epoch 67/100
# 449/449 - 0s - loss: 0.2475 - accuracy: 0.0000e+00
# Epoch 68/100
# 449/449 - 0s - loss: 0.2452 - accuracy: 0.0000e+00
# Epoch 69/100
# 449/449 - 0s - loss: 0.2460 - accuracy: 0.0000e+00
# Epoch 70/100
# 449/449 - 0s - loss: 0.2457 - accuracy: 0.0000e+00
# Epoch 71/100
# 449/449 - 0s - loss: 0.2468 - accuracy: 0.0000e+00
# Epoch 72/100
# 449/449 - 0s - loss: 0.2451 - accuracy: 0.0000e+00
# Epoch 73/100
# 449/449 - 0s - loss: 0.2456 - accuracy: 0.0000e+00
# Epoch 74/100
# 449/449 - 0s - loss: 0.2449 - accuracy: 0.0000e+00
# Epoch 75/100
# 449/449 - 0s - loss: 0.2429 - accuracy: 0.0000e+00
# Epoch 76/100
# 449/449 - 0s - loss: 0.2438 - accuracy: 0.0000e+00
# Epoch 77/100
# 449/449 - 0s - loss: 0.2442 - accuracy: 0.0000e+00
# Epoch 78/100
# 449/449 - 0s - loss: 0.2439 - accuracy: 0.0000e+00
# Epoch 79/100
# 449/449 - 0s - loss: 0.2407 - accuracy: 0.0000e+00
# Epoch 80/100
# 449/449 - 0s - loss: 0.2425 - accuracy: 0.0000e+00
# Epoch 81/100
# 449/449 - 0s - loss: 0.2410 - accuracy: 0.0000e+00
# Epoch 82/100
# 449/449 - 0s - loss: 0.2415 - accuracy: 0.0000e+00
# Epoch 83/100
# 449/449 - 0s - loss: 0.2421 - accuracy: 0.0000e+00
# Epoch 84/100
# 449/449 - 0s - loss: 0.2393 - accuracy: 0.0000e+00
# Epoch 85/100
# 449/449 - 0s - loss: 0.2379 - accuracy: 0.0000e+00
# Epoch 86/100
# 449/449 - 0s - loss: 0.2415 - accuracy: 0.0000e+00
# Epoch 87/100
# 449/449 - 0s - loss: 0.2407 - accuracy: 0.0000e+00
# Epoch 88/100
# 449/449 - 0s - loss: 0.2377 - accuracy: 0.0000e+00
# Epoch 89/100
# 449/449 - 0s - loss: 0.2395 - accuracy: 0.0000e+00
# Epoch 90/100
# 449/449 - 0s - loss: 0.2379 - accuracy: 0.0000e+00
# Epoch 91/100
# 449/449 - 0s - loss: 0.2367 - accuracy: 0.0000e+00
# Epoch 92/100
# 449/449 - 0s - loss: 0.2367 - accuracy: 0.0000e+00
# Epoch 93/100
# 449/449 - 0s - loss: 0.2387 - accuracy: 0.0000e+00
# Epoch 94/100
# 449/449 - 0s - loss: 0.2376 - accuracy: 0.0000e+00
# Epoch 95/100
# 449/449 - 0s - loss: 0.2372 - accuracy: 0.0000e+00
# Epoch 96/100
# 449/449 - 0s - loss: 0.2348 - accuracy: 0.0000e+00
# Epoch 97/100
# 449/449 - 0s - loss: 0.2356 - accuracy: 0.0000e+00
# Epoch 98/100
# 449/449 - 0s - loss: 0.2379 - accuracy: 0.0000e+00
# Epoch 99/100
# 449/449 - 0s - loss: 0.2354 - accuracy: 0.0000e+00
# Epoch 100/100
# 449/449 - 0s - loss: 0.2392 - accuracy: 0.0000e+00
# 50/50 - 0s - loss: 0.4523 - accuracy: 0.0000e+00
# Train on 449 samples
# Epoch 1/100
# 449/449 - 0s - loss: 0.7911 - accuracy: 0.0000e+00
# Epoch 2/100
# 449/449 - 0s - loss: 0.4909 - accuracy: 0.0000e+00
# Epoch 3/100
# 449/449 - 0s - loss: 0.3694 - accuracy: 0.0000e+00
# Epoch 4/100
# 449/449 - 0s - loss: 0.3422 - accuracy: 0.0000e+00
# Epoch 5/100
# 449/449 - 0s - loss: 0.3266 - accuracy: 0.0000e+00
# Epoch 6/100
# 449/449 - 0s - loss: 0.3163 - accuracy: 0.0000e+00
# Epoch 7/100
# 449/449 - 0s - loss: 0.3053 - accuracy: 0.0000e+00
# Epoch 8/100
# 449/449 - 0s - loss: 0.3004 - accuracy: 0.0000e+00
# Epoch 9/100
# 449/449 - 0s - loss: 0.2954 - accuracy: 0.0000e+00
# Epoch 10/100
# 449/449 - 0s - loss: 0.2953 - accuracy: 0.0000e+00
# Epoch 11/100
# 449/449 - 0s - loss: 0.2886 - accuracy: 0.0000e+00
# Epoch 12/100
# 449/449 - 0s - loss: 0.2852 - accuracy: 0.0000e+00
# Epoch 13/100
# 449/449 - 0s - loss: 0.2809 - accuracy: 0.0000e+00
# Epoch 14/100
# 449/449 - 0s - loss: 0.2796 - accuracy: 0.0000e+00
# Epoch 15/100
# 449/449 - 0s - loss: 0.2776 - accuracy: 0.0000e+00
# Epoch 16/100
# 449/449 - 0s - loss: 0.2750 - accuracy: 0.0000e+00
# Epoch 17/100
# 449/449 - 0s - loss: 0.2738 - accuracy: 0.0000e+00
# Epoch 18/100
# 449/449 - 0s - loss: 0.2716 - accuracy: 0.0000e+00
# Epoch 19/100
# 449/449 - 0s - loss: 0.2686 - accuracy: 0.0000e+00
# Epoch 20/100
# 449/449 - 0s - loss: 0.2675 - accuracy: 0.0000e+00
# Epoch 21/100
# 449/449 - 0s - loss: 0.2661 - accuracy: 0.0000e+00
# Epoch 22/100
# 449/449 - 0s - loss: 0.2652 - accuracy: 0.0000e+00
# Epoch 23/100
# 449/449 - 0s - loss: 0.2633 - accuracy: 0.0000e+00
# Epoch 24/100
# 449/449 - 0s - loss: 0.2637 - accuracy: 0.0000e+00
# Epoch 25/100
# 449/449 - 0s - loss: 0.2633 - accuracy: 0.0000e+00
# Epoch 26/100
# 449/449 - 0s - loss: 0.2632 - accuracy: 0.0000e+00
# Epoch 27/100
# 449/449 - 0s - loss: 0.2603 - accuracy: 0.0000e+00
# Epoch 28/100
# 449/449 - 0s - loss: 0.2595 - accuracy: 0.0000e+00
# Epoch 29/100
# 449/449 - 0s - loss: 0.2599 - accuracy: 0.0000e+00
# Epoch 30/100
# 449/449 - 0s - loss: 0.2562 - accuracy: 0.0000e+00
# Epoch 31/100
# 449/449 - 0s - loss: 0.2561 - accuracy: 0.0000e+00
# Epoch 32/100
# 449/449 - 0s - loss: 0.2551 - accuracy: 0.0000e+00
# Epoch 33/100
# 449/449 - 0s - loss: 0.2547 - accuracy: 0.0000e+00
# Epoch 34/100
# 449/449 - 0s - loss: 0.2532 - accuracy: 0.0000e+00
# Epoch 35/100
# 449/449 - 0s - loss: 0.2521 - accuracy: 0.0000e+00
# Epoch 36/100
# 449/449 - 0s - loss: 0.2518 - accuracy: 0.0000e+00
# Epoch 37/100
# 449/449 - 0s - loss: 0.2514 - accuracy: 0.0000e+00
# Epoch 38/100
# 449/449 - 0s - loss: 0.2506 - accuracy: 0.0000e+00
# Epoch 39/100
# 449/449 - 0s - loss: 0.2491 - accuracy: 0.0000e+00
# Epoch 40/100
# 449/449 - 0s - loss: 0.2503 - accuracy: 0.0000e+00
# Epoch 41/100
# 449/449 - 0s - loss: 0.2487 - accuracy: 0.0000e+00
# Epoch 42/100
# 449/449 - 0s - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 43/100
# 449/449 - 0s - loss: 0.2487 - accuracy: 0.0000e+00
# Epoch 44/100
# 449/449 - 0s - loss: 0.2479 - accuracy: 0.0000e+00
# Epoch 45/100
# 449/449 - 0s - loss: 0.2461 - accuracy: 0.0000e+00
# Epoch 46/100
# 449/449 - 0s - loss: 0.2453 - accuracy: 0.0000e+00
# Epoch 47/100
# 449/449 - 0s - loss: 0.2459 - accuracy: 0.0000e+00
# Epoch 48/100
# 449/449 - 0s - loss: 0.2449 - accuracy: 0.0000e+00
# Epoch 49/100
# 449/449 - 0s - loss: 0.2451 - accuracy: 0.0000e+00
# Epoch 50/100
# 449/449 - 0s - loss: 0.2434 - accuracy: 0.0000e+00
# Epoch 51/100
# 449/449 - 0s - loss: 0.2431 - accuracy: 0.0000e+00
# Epoch 52/100
# 449/449 - 0s - loss: 0.2428 - accuracy: 0.0000e+00
# Epoch 53/100
# 449/449 - 0s - loss: 0.2422 - accuracy: 0.0000e+00
# Epoch 54/100
# 449/449 - 0s - loss: 0.2413 - accuracy: 0.0000e+00
# Epoch 55/100
# 449/449 - 0s - loss: 0.2440 - accuracy: 0.0000e+00
# Epoch 56/100
# 449/449 - 0s - loss: 0.2412 - accuracy: 0.0000e+00
# Epoch 57/100
# 449/449 - 0s - loss: 0.2410 - accuracy: 0.0000e+00
# Epoch 58/100
# 449/449 - 0s - loss: 0.2381 - accuracy: 0.0000e+00
# Epoch 59/100
# 449/449 - 0s - loss: 0.2422 - accuracy: 0.0000e+00
# Epoch 60/100
# 449/449 - 0s - loss: 0.2392 - accuracy: 0.0000e+00
# Epoch 61/100
# 449/449 - 0s - loss: 0.2390 - accuracy: 0.0000e+00
# Epoch 62/100
# 449/449 - 0s - loss: 0.2370 - accuracy: 0.0000e+00
# Epoch 63/100
# 449/449 - 0s - loss: 0.2367 - accuracy: 0.0000e+00
# Epoch 64/100
# 449/449 - 0s - loss: 0.2362 - accuracy: 0.0000e+00
# Epoch 65/100
# 449/449 - 0s - loss: 0.2382 - accuracy: 0.0000e+00
# Epoch 66/100
# 449/449 - 0s - loss: 0.2353 - accuracy: 0.0000e+00
# Epoch 67/100
# 449/449 - 0s - loss: 0.2364 - accuracy: 0.0000e+00
# Epoch 68/100
# 449/449 - 0s - loss: 0.2363 - accuracy: 0.0000e+00
# Epoch 69/100
# 449/449 - 0s - loss: 0.2346 - accuracy: 0.0000e+00
# Epoch 70/100
# 449/449 - 0s - loss: 0.2339 - accuracy: 0.0000e+00
# Epoch 71/100
# 449/449 - 0s - loss: 0.2360 - accuracy: 0.0000e+00
# Epoch 72/100
# 449/449 - 0s - loss: 0.2332 - accuracy: 0.0000e+00
# Epoch 73/100
# 449/449 - 0s - loss: 0.2335 - accuracy: 0.0000e+00
# Epoch 74/100
# 449/449 - 0s - loss: 0.2329 - accuracy: 0.0000e+00
# Epoch 75/100
# 449/449 - 0s - loss: 0.2333 - accuracy: 0.0000e+00
# Epoch 76/100
# 449/449 - 0s - loss: 0.2328 - accuracy: 0.0000e+00
# Epoch 77/100
# 449/449 - 0s - loss: 0.2334 - accuracy: 0.0000e+00
# Epoch 78/100
# 449/449 - 0s - loss: 0.2336 - accuracy: 0.0000e+00
# Epoch 79/100
# 449/449 - 0s - loss: 0.2315 - accuracy: 0.0000e+00
# Epoch 80/100
# 449/449 - 0s - loss: 0.2323 - accuracy: 0.0000e+00
# Epoch 81/100
# 449/449 - 0s - loss: 0.2308 - accuracy: 0.0000e+00
# Epoch 82/100
# 449/449 - 0s - loss: 0.2310 - accuracy: 0.0000e+00
# Epoch 83/100
# 449/449 - 0s - loss: 0.2309 - accuracy: 0.0000e+00
# Epoch 84/100
# 449/449 - 0s - loss: 0.2299 - accuracy: 0.0000e+00
# Epoch 85/100
# 449/449 - 0s - loss: 0.2314 - accuracy: 0.0000e+00
# Epoch 86/100
# 449/449 - 0s - loss: 0.2305 - accuracy: 0.0000e+00
# Epoch 87/100
# 449/449 - 0s - loss: 0.2287 - accuracy: 0.0000e+00
# Epoch 88/100
# 449/449 - 0s - loss: 0.2289 - accuracy: 0.0000e+00
# Epoch 89/100
# 449/449 - 0s - loss: 0.2298 - accuracy: 0.0000e+00
# Epoch 90/100
# 449/449 - 0s - loss: 0.2294 - accuracy: 0.0000e+00
# Epoch 91/100
# 449/449 - 0s - loss: 0.2282 - accuracy: 0.0000e+00
# Epoch 92/100
# 449/449 - 0s - loss: 0.2291 - accuracy: 0.0000e+00
# Epoch 93/100
# 449/449 - 0s - loss: 0.2293 - accuracy: 0.0000e+00
# Epoch 94/100
# 449/449 - 0s - loss: 0.2276 - accuracy: 0.0000e+00
# Epoch 95/100
# 449/449 - 0s - loss: 0.2281 - accuracy: 0.0000e+00
# Epoch 96/100
# 449/449 - 0s - loss: 0.2292 - accuracy: 0.0000e+00
# Epoch 97/100
# 449/449 - 0s - loss: 0.2271 - accuracy: 0.0000e+00
# Epoch 98/100
# 449/449 - 0s - loss: 0.2263 - accuracy: 0.0000e+00
# Epoch 99/100
# 449/449 - 0s - loss: 0.2269 - accuracy: 0.0000e+00
# Epoch 100/100
# 449/449 - 0s - loss: 0.2266 - accuracy: 0.0000e+00
# 50/50 - 0s - loss: 0.5657 - accuracy: 0.0000e+00
# Train on 449 samples
# Epoch 1/100
# 449/449 - 0s - loss: 0.9646 - accuracy: 0.0000e+00
# Epoch 2/100
# 449/449 - 0s - loss: 0.6261 - accuracy: 0.0000e+00
# Epoch 3/100
# 449/449 - 0s - loss: 0.4633 - accuracy: 0.0000e+00
# Epoch 4/100
# 449/449 - 0s - loss: 0.4175 - accuracy: 0.0000e+00
# Epoch 5/100
# 449/449 - 0s - loss: 0.3829 - accuracy: 0.0000e+00
# Epoch 6/100
# 449/449 - 0s - loss: 0.3656 - accuracy: 0.0000e+00
# Epoch 7/100
# 449/449 - 0s - loss: 0.3544 - accuracy: 0.0000e+00
# Epoch 8/100
# 449/449 - 0s - loss: 0.3449 - accuracy: 0.0000e+00
# Epoch 9/100
# 449/449 - 0s - loss: 0.3411 - accuracy: 0.0000e+00
# Epoch 10/100
# 449/449 - 0s - loss: 0.3338 - accuracy: 0.0000e+00
# Epoch 11/100
# 449/449 - 0s - loss: 0.3311 - accuracy: 0.0000e+00
# Epoch 12/100
# 449/449 - 0s - loss: 0.3257 - accuracy: 0.0000e+00
# Epoch 13/100
# 449/449 - 0s - loss: 0.3243 - accuracy: 0.0000e+00
# Epoch 14/100
# 449/449 - 0s - loss: 0.3215 - accuracy: 0.0000e+00
# Epoch 15/100
# 449/449 - 0s - loss: 0.3181 - accuracy: 0.0000e+00
# Epoch 16/100
# 449/449 - 0s - loss: 0.3137 - accuracy: 0.0000e+00
# Epoch 17/100
# 449/449 - 0s - loss: 0.3112 - accuracy: 0.0000e+00
# Epoch 18/100
# 449/449 - 0s - loss: 0.3092 - accuracy: 0.0000e+00
# Epoch 19/100
# 449/449 - 0s - loss: 0.3080 - accuracy: 0.0000e+00
# Epoch 20/100
# 449/449 - 0s - loss: 0.3047 - accuracy: 0.0000e+00
# Epoch 21/100
# 449/449 - 0s - loss: 0.3030 - accuracy: 0.0000e+00
# Epoch 22/100
# 449/449 - 0s - loss: 0.3016 - accuracy: 0.0000e+00
# Epoch 23/100
# 449/449 - 0s - loss: 0.2989 - accuracy: 0.0000e+00
# Epoch 24/100
# 449/449 - 0s - loss: 0.2970 - accuracy: 0.0000e+00
# Epoch 25/100
# 449/449 - 0s - loss: 0.2966 - accuracy: 0.0000e+00
# Epoch 26/100
# 449/449 - 0s - loss: 0.2953 - accuracy: 0.0000e+00
# Epoch 27/100
# 449/449 - 0s - loss: 0.2908 - accuracy: 0.0000e+00
# Epoch 28/100
# 449/449 - 0s - loss: 0.2900 - accuracy: 0.0000e+00
# Epoch 29/100
# 449/449 - 0s - loss: 0.2882 - accuracy: 0.0000e+00
# Epoch 30/100
# 449/449 - 0s - loss: 0.2869 - accuracy: 0.0000e+00
# Epoch 31/100
# 449/449 - 0s - loss: 0.2851 - accuracy: 0.0000e+00
# Epoch 32/100
# 449/449 - 0s - loss: 0.2824 - accuracy: 0.0000e+00
# Epoch 33/100
# 449/449 - 0s - loss: 0.2852 - accuracy: 0.0000e+00
# Epoch 34/100
# 449/449 - 0s - loss: 0.2817 - accuracy: 0.0000e+00
# Epoch 35/100
# 449/449 - 0s - loss: 0.2808 - accuracy: 0.0000e+00
# Epoch 36/100
# 449/449 - 0s - loss: 0.2785 - accuracy: 0.0000e+00
# Epoch 37/100
# 449/449 - 0s - loss: 0.2787 - accuracy: 0.0000e+00
# Epoch 38/100
# 449/449 - 0s - loss: 0.2797 - accuracy: 0.0000e+00
# Epoch 39/100
# 449/449 - 0s - loss: 0.2770 - accuracy: 0.0000e+00
# Epoch 40/100
# 449/449 - 0s - loss: 0.2756 - accuracy: 0.0000e+00
# Epoch 41/100
# 449/449 - 0s - loss: 0.2777 - accuracy: 0.0000e+00
# Epoch 42/100
# 449/449 - 0s - loss: 0.2744 - accuracy: 0.0000e+00
# Epoch 43/100
# 449/449 - 0s - loss: 0.2747 - accuracy: 0.0000e+00
# Epoch 44/100
# 449/449 - 0s - loss: 0.2724 - accuracy: 0.0000e+00
# Epoch 45/100
# 449/449 - 0s - loss: 0.2720 - accuracy: 0.0000e+00
# Epoch 46/100
# 449/449 - 0s - loss: 0.2724 - accuracy: 0.0000e+00
# Epoch 47/100
# 449/449 - 0s - loss: 0.2705 - accuracy: 0.0000e+00
# Epoch 48/100
# 449/449 - 0s - loss: 0.2731 - accuracy: 0.0000e+00
# Epoch 49/100
# 449/449 - 0s - loss: 0.2679 - accuracy: 0.0000e+00
# Epoch 50/100
# 449/449 - 0s - loss: 0.2692 - accuracy: 0.0000e+00
# Epoch 51/100
# 449/449 - 0s - loss: 0.2688 - accuracy: 0.0000e+00
# Epoch 52/100
# 449/449 - 0s - loss: 0.2681 - accuracy: 0.0000e+00
# Epoch 53/100
# 449/449 - 0s - loss: 0.2682 - accuracy: 0.0000e+00
# Epoch 54/100
# 449/449 - 0s - loss: 0.2702 - accuracy: 0.0000e+00
# Epoch 55/100
# 449/449 - 0s - loss: 0.2675 - accuracy: 0.0000e+00
# Epoch 56/100
# 449/449 - 0s - loss: 0.2663 - accuracy: 0.0000e+00
# Epoch 57/100
# 449/449 - 0s - loss: 0.2659 - accuracy: 0.0000e+00
# Epoch 58/100
# 449/449 - 0s - loss: 0.2649 - accuracy: 0.0000e+00
# Epoch 59/100
# 449/449 - 0s - loss: 0.2636 - accuracy: 0.0000e+00
# Epoch 60/100
# 449/449 - 0s - loss: 0.2671 - accuracy: 0.0000e+00
# Epoch 61/100
# 449/449 - 0s - loss: 0.2646 - accuracy: 0.0000e+00
# Epoch 62/100
# 449/449 - 0s - loss: 0.2614 - accuracy: 0.0000e+00
# Epoch 63/100
# 449/449 - 0s - loss: 0.2625 - accuracy: 0.0000e+00
# Epoch 64/100
# 449/449 - 0s - loss: 0.2619 - accuracy: 0.0000e+00
# Epoch 65/100
# 449/449 - 0s - loss: 0.2606 - accuracy: 0.0000e+00
# Epoch 66/100
# 449/449 - 0s - loss: 0.2626 - accuracy: 0.0000e+00
# Epoch 67/100
# 449/449 - 0s - loss: 0.2610 - accuracy: 0.0000e+00
# Epoch 68/100
# 449/449 - 0s - loss: 0.2591 - accuracy: 0.0000e+00
# Epoch 69/100
# 449/449 - 0s - loss: 0.2603 - accuracy: 0.0000e+00
# Epoch 70/100
# 449/449 - 0s - loss: 0.2590 - accuracy: 0.0000e+00
# Epoch 71/100
# 449/449 - 0s - loss: 0.2584 - accuracy: 0.0000e+00
# Epoch 72/100
# 449/449 - 0s - loss: 0.2579 - accuracy: 0.0000e+00
# Epoch 73/100
# 449/449 - 0s - loss: 0.2576 - accuracy: 0.0000e+00
# Epoch 74/100
# 449/449 - 0s - loss: 0.2570 - accuracy: 0.0000e+00
# Epoch 75/100
# 449/449 - 0s - loss: 0.2600 - accuracy: 0.0000e+00
# Epoch 76/100
# 449/449 - 0s - loss: 0.2558 - accuracy: 0.0000e+00
# Epoch 77/100
# 449/449 - 0s - loss: 0.2593 - accuracy: 0.0000e+00
# Epoch 78/100
# 449/449 - 0s - loss: 0.2548 - accuracy: 0.0000e+00
# Epoch 79/100
# 449/449 - 0s - loss: 0.2573 - accuracy: 0.0000e+00
# Epoch 80/100
# 449/449 - 0s - loss: 0.2590 - accuracy: 0.0000e+00
# Epoch 81/100
# 449/449 - 0s - loss: 0.2563 - accuracy: 0.0000e+00
# Epoch 82/100
# 449/449 - 0s - loss: 0.2546 - accuracy: 0.0000e+00
# Epoch 83/100
# 449/449 - 0s - loss: 0.2530 - accuracy: 0.0000e+00
# Epoch 84/100
# 449/449 - 0s - loss: 0.2554 - accuracy: 0.0000e+00
# Epoch 85/100
# 449/449 - 0s - loss: 0.2527 - accuracy: 0.0000e+00
# Epoch 86/100
# 449/449 - 0s - loss: 0.2563 - accuracy: 0.0000e+00
# Epoch 87/100
# 449/449 - 0s - loss: 0.2555 - accuracy: 0.0000e+00
# Epoch 88/100
# 449/449 - 0s - loss: 0.2553 - accuracy: 0.0000e+00
# Epoch 89/100
# 449/449 - 0s - loss: 0.2507 - accuracy: 0.0000e+00
# Epoch 90/100
# 449/449 - 0s - loss: 0.2524 - accuracy: 0.0000e+00
# Epoch 91/100
# 449/449 - 0s - loss: 0.2536 - accuracy: 0.0000e+00
# Epoch 92/100
# 449/449 - 0s - loss: 0.2498 - accuracy: 0.0000e+00
# Epoch 93/100
# 449/449 - 0s - loss: 0.2515 - accuracy: 0.0000e+00
# Epoch 94/100
# 449/449 - 0s - loss: 0.2520 - accuracy: 0.0000e+00
# Epoch 95/100
# 449/449 - 0s - loss: 0.2498 - accuracy: 0.0000e+00
# Epoch 96/100
# 449/449 - 0s - loss: 0.2509 - accuracy: 0.0000e+00
# Epoch 97/100
# 449/449 - 0s - loss: 0.2500 - accuracy: 0.0000e+00
# Epoch 98/100
# 449/449 - 0s - loss: 0.2477 - accuracy: 0.0000e+00
# Epoch 99/100
# 449/449 - 0s - loss: 0.2485 - accuracy: 0.0000e+00
# Epoch 100/100
# 449/449 - 0s - loss: 0.2493 - accuracy: 0.0000e+00
# 50/50 - 0s - loss: 0.2252 - accuracy: 0.0000e+00
# Train on 449 samples
# Epoch 1/100
# 449/449 - 0s - loss: 0.8993 - accuracy: 0.0000e+00
# Epoch 2/100
# 449/449 - 0s - loss: 0.6497 - accuracy: 0.0000e+00
# Epoch 3/100
# 449/449 - 0s - loss: 0.5228 - accuracy: 0.0000e+00
# Epoch 4/100
# 449/449 - 0s - loss: 0.4517 - accuracy: 0.0000e+00
# Epoch 5/100
# 449/449 - 0s - loss: 0.4129 - accuracy: 0.0000e+00
# Epoch 6/100
# 449/449 - 0s - loss: 0.3939 - accuracy: 0.0000e+00
# Epoch 7/100
# 449/449 - 0s - loss: 0.3797 - accuracy: 0.0000e+00
# Epoch 8/100
# 449/449 - 0s - loss: 0.3674 - accuracy: 0.0000e+00
# Epoch 9/100
# 449/449 - 0s - loss: 0.3615 - accuracy: 0.0000e+00
# Epoch 10/100
# 449/449 - 0s - loss: 0.3529 - accuracy: 0.0000e+00
# Epoch 11/100
# 449/449 - 0s - loss: 0.3480 - accuracy: 0.0000e+00
# Epoch 12/100
# 449/449 - 0s - loss: 0.3478 - accuracy: 0.0000e+00
# Epoch 13/100
# 449/449 - 0s - loss: 0.3418 - accuracy: 0.0000e+00
# Epoch 14/100
# 449/449 - 0s - loss: 0.3401 - accuracy: 0.0000e+00
# Epoch 15/100
# 449/449 - 0s - loss: 0.3352 - accuracy: 0.0000e+00
# Epoch 16/100
# 449/449 - 0s - loss: 0.3330 - accuracy: 0.0000e+00
# Epoch 17/100
# 449/449 - 0s - loss: 0.3298 - accuracy: 0.0000e+00
# Epoch 18/100
# 449/449 - 0s - loss: 0.3263 - accuracy: 0.0000e+00
# Epoch 19/100
# 449/449 - 0s - loss: 0.3257 - accuracy: 0.0000e+00
# Epoch 20/100
# 449/449 - 0s - loss: 0.3249 - accuracy: 0.0000e+00
# Epoch 21/100
# 449/449 - 0s - loss: 0.3212 - accuracy: 0.0000e+00
# Epoch 22/100
# 449/449 - 0s - loss: 0.3192 - accuracy: 0.0000e+00
# Epoch 23/100
# 449/449 - 0s - loss: 0.3190 - accuracy: 0.0000e+00
# Epoch 24/100
# 449/449 - 0s - loss: 0.3177 - accuracy: 0.0000e+00
# Epoch 25/100
# 449/449 - 0s - loss: 0.3157 - accuracy: 0.0000e+00
# Epoch 26/100
# 449/449 - 0s - loss: 0.3130 - accuracy: 0.0000e+00
# Epoch 27/100
# 449/449 - 0s - loss: 0.3121 - accuracy: 0.0000e+00
# Epoch 28/100
# 449/449 - 0s - loss: 0.3110 - accuracy: 0.0000e+00
# Epoch 29/100
# 449/449 - 0s - loss: 0.3088 - accuracy: 0.0000e+00
# Epoch 30/100
# 449/449 - 0s - loss: 0.3058 - accuracy: 0.0000e+00
# Epoch 31/100
# 449/449 - 0s - loss: 0.3072 - accuracy: 0.0000e+00
# Epoch 32/100
# 449/449 - 0s - loss: 0.3052 - accuracy: 0.0000e+00
# Epoch 33/100
# 449/449 - 0s - loss: 0.3049 - accuracy: 0.0000e+00
# Epoch 34/100
# 449/449 - 0s - loss: 0.3034 - accuracy: 0.0000e+00
# Epoch 35/100
# 449/449 - 0s - loss: 0.3035 - accuracy: 0.0000e+00
# Epoch 36/100
# 449/449 - 0s - loss: 0.3017 - accuracy: 0.0000e+00
# Epoch 37/100
# 449/449 - 0s - loss: 0.3000 - accuracy: 0.0000e+00
# Epoch 38/100
# 449/449 - 0s - loss: 0.2990 - accuracy: 0.0000e+00
# Epoch 39/100
# 449/449 - 0s - loss: 0.2978 - accuracy: 0.0000e+00
# Epoch 40/100
# 449/449 - 0s - loss: 0.2967 - accuracy: 0.0000e+00
# Epoch 41/100
# 449/449 - 0s - loss: 0.2962 - accuracy: 0.0000e+00
# Epoch 42/100
# 449/449 - 0s - loss: 0.2947 - accuracy: 0.0000e+00
# Epoch 43/100
# 449/449 - 0s - loss: 0.2945 - accuracy: 0.0000e+00
# Epoch 44/100
# 449/449 - 0s - loss: 0.2934 - accuracy: 0.0000e+00
# Epoch 45/100
# 449/449 - 0s - loss: 0.2929 - accuracy: 0.0000e+00
# Epoch 46/100
# 449/449 - 0s - loss: 0.2926 - accuracy: 0.0000e+00
# Epoch 47/100
# 449/449 - 0s - loss: 0.2933 - accuracy: 0.0000e+00
# Epoch 48/100
# 449/449 - 0s - loss: 0.2892 - accuracy: 0.0000e+00
# Epoch 49/100
# 449/449 - 0s - loss: 0.2898 - accuracy: 0.0000e+00
# Epoch 50/100
# 449/449 - 0s - loss: 0.2892 - accuracy: 0.0000e+00
# Epoch 51/100
# 449/449 - 0s - loss: 0.2869 - accuracy: 0.0000e+00
# Epoch 52/100
# 449/449 - 0s - loss: 0.2879 - accuracy: 0.0000e+00
# Epoch 53/100
# 449/449 - 0s - loss: 0.2872 - accuracy: 0.0000e+00
# Epoch 54/100
# 449/449 - 0s - loss: 0.2859 - accuracy: 0.0000e+00
# Epoch 55/100
# 449/449 - 0s - loss: 0.2867 - accuracy: 0.0000e+00
# Epoch 56/100
# 449/449 - 0s - loss: 0.2872 - accuracy: 0.0000e+00
# Epoch 57/100
# 449/449 - 0s - loss: 0.2839 - accuracy: 0.0000e+00
# Epoch 58/100
# 449/449 - 0s - loss: 0.2839 - accuracy: 0.0000e+00
# Epoch 59/100
# 449/449 - 0s - loss: 0.2816 - accuracy: 0.0000e+00
# Epoch 60/100
# 449/449 - 0s - loss: 0.2825 - accuracy: 0.0000e+00
# Epoch 61/100
# 449/449 - 0s - loss: 0.2813 - accuracy: 0.0000e+00
# Epoch 62/100
# 449/449 - 0s - loss: 0.2808 - accuracy: 0.0000e+00
# Epoch 63/100
# 449/449 - 0s - loss: 0.2801 - accuracy: 0.0000e+00
# Epoch 64/100
# 449/449 - 0s - loss: 0.2795 - accuracy: 0.0000e+00
# Epoch 65/100
# 449/449 - 0s - loss: 0.2790 - accuracy: 0.0000e+00
# Epoch 66/100
# 449/449 - 0s - loss: 0.2776 - accuracy: 0.0000e+00
# Epoch 67/100
# 449/449 - 0s - loss: 0.2764 - accuracy: 0.0000e+00
# Epoch 68/100
# 449/449 - 0s - loss: 0.2772 - accuracy: 0.0000e+00
# Epoch 69/100
# 449/449 - 0s - loss: 0.2749 - accuracy: 0.0000e+00
# Epoch 70/100
# 449/449 - 0s - loss: 0.2757 - accuracy: 0.0000e+00
# Epoch 71/100
# 449/449 - 0s - loss: 0.2759 - accuracy: 0.0000e+00
# Epoch 72/100
# 449/449 - 0s - loss: 0.2739 - accuracy: 0.0000e+00
# Epoch 73/100
# 449/449 - 0s - loss: 0.2727 - accuracy: 0.0000e+00
# Epoch 74/100
# 449/449 - 0s - loss: 0.2727 - accuracy: 0.0000e+00
# Epoch 75/100
# 449/449 - 0s - loss: 0.2736 - accuracy: 0.0000e+00
# Epoch 76/100
# 449/449 - 0s - loss: 0.2717 - accuracy: 0.0000e+00
# Epoch 77/100
# 449/449 - 0s - loss: 0.2717 - accuracy: 0.0000e+00
# Epoch 78/100
# 449/449 - 0s - loss: 0.2694 - accuracy: 0.0000e+00
# Epoch 79/100
# 449/449 - 0s - loss: 0.2698 - accuracy: 0.0000e+00
# Epoch 80/100
# 449/449 - 0s - loss: 0.2710 - accuracy: 0.0000e+00
# Epoch 81/100
# 449/449 - 0s - loss: 0.2700 - accuracy: 0.0000e+00
# Epoch 82/100
# 449/449 - 0s - loss: 0.2678 - accuracy: 0.0000e+00
# Epoch 83/100
# 449/449 - 0s - loss: 0.2694 - accuracy: 0.0000e+00
# Epoch 84/100
# 449/449 - 0s - loss: 0.2679 - accuracy: 0.0000e+00
# Epoch 85/100
# 449/449 - 0s - loss: 0.2664 - accuracy: 0.0000e+00
# Epoch 86/100
# 449/449 - 0s - loss: 0.2682 - accuracy: 0.0000e+00
# Epoch 87/100
# 449/449 - 0s - loss: 0.2676 - accuracy: 0.0000e+00
# Epoch 88/100
# 449/449 - 0s - loss: 0.2669 - accuracy: 0.0000e+00
# Epoch 89/100
# 449/449 - 0s - loss: 0.2662 - accuracy: 0.0000e+00
# Epoch 90/100
# 449/449 - 0s - loss: 0.2646 - accuracy: 0.0000e+00
# Epoch 91/100
# 449/449 - 0s - loss: 0.2656 - accuracy: 0.0000e+00
# Epoch 92/100
# 449/449 - 0s - loss: 0.2650 - accuracy: 0.0000e+00
# Epoch 93/100
# 449/449 - 0s - loss: 0.2629 - accuracy: 0.0000e+00
# Epoch 94/100
# 449/449 - 0s - loss: 0.2647 - accuracy: 0.0000e+00
# Epoch 95/100
# 449/449 - 0s - loss: 0.2646 - accuracy: 0.0000e+00
# Epoch 96/100
# 449/449 - 0s - loss: 0.2603 - accuracy: 0.0000e+00
# Epoch 97/100
# 449/449 - 0s - loss: 0.2613 - accuracy: 0.0000e+00
# Epoch 98/100
# 449/449 - 0s - loss: 0.2608 - accuracy: 0.0000e+00
# Epoch 99/100
# 449/449 - 0s - loss: 0.2616 - accuracy: 0.0000e+00
# Epoch 100/100
# 449/449 - 0s - loss: 0.2599 - accuracy: 0.0000e+00
# 50/50 - 0s - loss: 0.1615 - accuracy: 0.0000e+00
# Train on 449 samples
# Epoch 1/100
# 449/449 - 0s - loss: 0.8254 - accuracy: 0.0000e+00
# Epoch 2/100
# 449/449 - 0s - loss: 0.4834 - accuracy: 0.0000e+00
# Epoch 3/100
# 449/449 - 0s - loss: 0.3895 - accuracy: 0.0000e+00
# Epoch 4/100
# 449/449 - 0s - loss: 0.3651 - accuracy: 0.0000e+00
# Epoch 5/100
# 449/449 - 0s - loss: 0.3476 - accuracy: 0.0000e+00
# Epoch 6/100
# 449/449 - 0s - loss: 0.3352 - accuracy: 0.0000e+00
# Epoch 7/100
# 449/449 - 0s - loss: 0.3283 - accuracy: 0.0000e+00
# Epoch 8/100
# 449/449 - 0s - loss: 0.3189 - accuracy: 0.0000e+00
# Epoch 9/100
# 449/449 - 0s - loss: 0.3138 - accuracy: 0.0000e+00
# Epoch 10/100
# 449/449 - 0s - loss: 0.3107 - accuracy: 0.0000e+00
# Epoch 11/100
# 449/449 - 0s - loss: 0.3072 - accuracy: 0.0000e+00
# Epoch 12/100
# 449/449 - 0s - loss: 0.3024 - accuracy: 0.0000e+00
# Epoch 13/100
# 449/449 - 0s - loss: 0.3026 - accuracy: 0.0000e+00
# Epoch 14/100
# 449/449 - 0s - loss: 0.3006 - accuracy: 0.0000e+00
# Epoch 15/100
# 449/449 - 0s - loss: 0.2978 - accuracy: 0.0000e+00
# Epoch 16/100
# 449/449 - 0s - loss: 0.2984 - accuracy: 0.0000e+00
# Epoch 17/100
# 449/449 - 0s - loss: 0.2975 - accuracy: 0.0000e+00
# Epoch 18/100
# 449/449 - 0s - loss: 0.2945 - accuracy: 0.0000e+00
# Epoch 19/100
# 449/449 - 0s - loss: 0.2921 - accuracy: 0.0000e+00
# Epoch 20/100
# 449/449 - 0s - loss: 0.2923 - accuracy: 0.0000e+00
# Epoch 21/100
# 449/449 - 0s - loss: 0.2930 - accuracy: 0.0000e+00
# Epoch 22/100
# 449/449 - 0s - loss: 0.2895 - accuracy: 0.0000e+00
# Epoch 23/100
# 449/449 - 0s - loss: 0.2901 - accuracy: 0.0000e+00
# Epoch 24/100
# 449/449 - 0s - loss: 0.2904 - accuracy: 0.0000e+00
# Epoch 25/100
# 449/449 - 0s - loss: 0.2875 - accuracy: 0.0000e+00
# Epoch 26/100
# 449/449 - 0s - loss: 0.2864 - accuracy: 0.0000e+00
# Epoch 27/100
# 449/449 - 0s - loss: 0.2857 - accuracy: 0.0000e+00
# Epoch 28/100
# 449/449 - 0s - loss: 0.2858 - accuracy: 0.0000e+00
# Epoch 29/100
# 449/449 - 0s - loss: 0.2831 - accuracy: 0.0000e+00
# Epoch 30/100
# 449/449 - 0s - loss: 0.2848 - accuracy: 0.0000e+00
# Epoch 31/100
# 449/449 - 0s - loss: 0.2829 - accuracy: 0.0000e+00
# Epoch 32/100
# 449/449 - 0s - loss: 0.2813 - accuracy: 0.0000e+00
# Epoch 33/100
# 449/449 - 0s - loss: 0.2790 - accuracy: 0.0000e+00
# Epoch 34/100
# 449/449 - 0s - loss: 0.2802 - accuracy: 0.0000e+00
# Epoch 35/100
# 449/449 - 0s - loss: 0.2794 - accuracy: 0.0000e+00
# Epoch 36/100
# 449/449 - 0s - loss: 0.2789 - accuracy: 0.0000e+00
# Epoch 37/100
# 449/449 - 0s - loss: 0.2782 - accuracy: 0.0000e+00
# Epoch 38/100
# 449/449 - 0s - loss: 0.2775 - accuracy: 0.0000e+00
# Epoch 39/100
# 449/449 - 0s - loss: 0.2775 - accuracy: 0.0000e+00
# Epoch 40/100
# 449/449 - 0s - loss: 0.2760 - accuracy: 0.0000e+00
# Epoch 41/100
# 449/449 - 0s - loss: 0.2755 - accuracy: 0.0000e+00
# Epoch 42/100
# 449/449 - 0s - loss: 0.2757 - accuracy: 0.0000e+00
# Epoch 43/100
# 449/449 - 0s - loss: 0.2733 - accuracy: 0.0000e+00
# Epoch 44/100
# 449/449 - 0s - loss: 0.2737 - accuracy: 0.0000e+00
# Epoch 45/100
# 449/449 - 0s - loss: 0.2740 - accuracy: 0.0000e+00
# Epoch 46/100
# 449/449 - 0s - loss: 0.2730 - accuracy: 0.0000e+00
# Epoch 47/100
# 449/449 - 0s - loss: 0.2701 - accuracy: 0.0000e+00
# Epoch 48/100
# 449/449 - 0s - loss: 0.2711 - accuracy: 0.0000e+00
# Epoch 49/100
# 449/449 - 0s - loss: 0.2710 - accuracy: 0.0000e+00
# Epoch 50/100
# 449/449 - 0s - loss: 0.2723 - accuracy: 0.0000e+00
# Epoch 51/100
# 449/449 - 0s - loss: 0.2701 - accuracy: 0.0000e+00
# Epoch 52/100
# 449/449 - 0s - loss: 0.2700 - accuracy: 0.0000e+00
# Epoch 53/100
# 449/449 - 0s - loss: 0.2682 - accuracy: 0.0000e+00
# Epoch 54/100
# 449/449 - 0s - loss: 0.2674 - accuracy: 0.0000e+00
# Epoch 55/100
# 449/449 - 0s - loss: 0.2661 - accuracy: 0.0000e+00
# Epoch 56/100
# 449/449 - 0s - loss: 0.2678 - accuracy: 0.0000e+00
# Epoch 57/100
# 449/449 - 0s - loss: 0.2673 - accuracy: 0.0000e+00
# Epoch 58/100
# 449/449 - 0s - loss: 0.2648 - accuracy: 0.0000e+00
# Epoch 59/100
# 449/449 - 0s - loss: 0.2663 - accuracy: 0.0000e+00
# Epoch 60/100
# 449/449 - 0s - loss: 0.2622 - accuracy: 0.0000e+00
# Epoch 61/100
# 449/449 - 0s - loss: 0.2664 - accuracy: 0.0000e+00
# Epoch 62/100
# 449/449 - 0s - loss: 0.2631 - accuracy: 0.0000e+00
# Epoch 63/100
# 449/449 - 0s - loss: 0.2628 - accuracy: 0.0000e+00
# Epoch 64/100
# 449/449 - 0s - loss: 0.2606 - accuracy: 0.0000e+00
# Epoch 65/100
# 449/449 - 0s - loss: 0.2598 - accuracy: 0.0000e+00
# Epoch 66/100
# 449/449 - 0s - loss: 0.2644 - accuracy: 0.0000e+00
# Epoch 67/100
# 449/449 - 0s - loss: 0.2616 - accuracy: 0.0000e+00
# Epoch 68/100
# 449/449 - 0s - loss: 0.2580 - accuracy: 0.0000e+00
# Epoch 69/100
# 449/449 - 0s - loss: 0.2582 - accuracy: 0.0000e+00
# Epoch 70/100
# 449/449 - 0s - loss: 0.2600 - accuracy: 0.0000e+00
# Epoch 71/100
# 449/449 - 0s - loss: 0.2598 - accuracy: 0.0000e+00
# Epoch 72/100
# 449/449 - 0s - loss: 0.2569 - accuracy: 0.0000e+00
# Epoch 73/100
# 449/449 - 0s - loss: 0.2556 - accuracy: 0.0000e+00
# Epoch 74/100
# 449/449 - 0s - loss: 0.2545 - accuracy: 0.0000e+00
# Epoch 75/100
# 449/449 - 0s - loss: 0.2552 - accuracy: 0.0000e+00
# Epoch 76/100
# 449/449 - 0s - loss: 0.2538 - accuracy: 0.0000e+00
# Epoch 77/100
# 449/449 - 0s - loss: 0.2546 - accuracy: 0.0000e+00
# Epoch 78/100
# 449/449 - 0s - loss: 0.2547 - accuracy: 0.0000e+00
# Epoch 79/100
# 449/449 - 0s - loss: 0.2560 - accuracy: 0.0000e+00
# Epoch 80/100
# 449/449 - 0s - loss: 0.2519 - accuracy: 0.0000e+00
# Epoch 81/100
# 449/449 - 0s - loss: 0.2525 - accuracy: 0.0000e+00
# Epoch 82/100
# 449/449 - 0s - loss: 0.2528 - accuracy: 0.0000e+00
# Epoch 83/100
# 449/449 - 0s - loss: 0.2506 - accuracy: 0.0000e+00
# Epoch 84/100
# 449/449 - 0s - loss: 0.2501 - accuracy: 0.0000e+00
# Epoch 85/100
# 449/449 - 0s - loss: 0.2509 - accuracy: 0.0000e+00
# Epoch 86/100
# 449/449 - 0s - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 87/100
# 449/449 - 0s - loss: 0.2477 - accuracy: 0.0000e+00
# Epoch 88/100
# 449/449 - 0s - loss: 0.2505 - accuracy: 0.0000e+00
# Epoch 89/100
# 449/449 - 0s - loss: 0.2488 - accuracy: 0.0000e+00
# Epoch 90/100
# 449/449 - 0s - loss: 0.2472 - accuracy: 0.0000e+00
# Epoch 91/100
# 449/449 - 0s - loss: 0.2478 - accuracy: 0.0000e+00
# Epoch 92/100
# 449/449 - 0s - loss: 0.2480 - accuracy: 0.0000e+00
# Epoch 93/100
# 449/449 - 0s - loss: 0.2462 - accuracy: 0.0000e+00
# Epoch 94/100
# 449/449 - 0s - loss: 0.2447 - accuracy: 0.0000e+00
# Epoch 95/100
# 449/449 - 0s - loss: 0.2472 - accuracy: 0.0000e+00
# Epoch 96/100
# 449/449 - 0s - loss: 0.2439 - accuracy: 0.0000e+00
# Epoch 97/100
# 449/449 - 0s - loss: 0.2440 - accuracy: 0.0000e+00
# Epoch 98/100
# 449/449 - 0s - loss: 0.2470 - accuracy: 0.0000e+00
# Epoch 99/100
# 449/449 - 0s - loss: 0.2424 - accuracy: 0.0000e+00
# Epoch 100/100
# 449/449 - 0s - loss: 0.2424 - accuracy: 0.0000e+00
# 50/50 - 0s - loss: 0.3070 - accuracy: 0.0000e+00
# Train on 449 samples
# Epoch 1/100
# 449/449 - 0s - loss: 0.8555 - accuracy: 0.0000e+00
# Epoch 2/100
# 449/449 - 0s - loss: 0.5581 - accuracy: 0.0000e+00
# Epoch 3/100
# 449/449 - 0s - loss: 0.4391 - accuracy: 0.0000e+00
# Epoch 4/100
# 449/449 - 0s - loss: 0.3988 - accuracy: 0.0000e+00
# Epoch 5/100
# 449/449 - 0s - loss: 0.3741 - accuracy: 0.0000e+00
# Epoch 6/100
# 449/449 - 0s - loss: 0.3556 - accuracy: 0.0000e+00
# Epoch 7/100
# 449/449 - 0s - loss: 0.3417 - accuracy: 0.0000e+00
# Epoch 8/100
# 449/449 - 0s - loss: 0.3314 - accuracy: 0.0000e+00
# Epoch 9/100
# 449/449 - 0s - loss: 0.3213 - accuracy: 0.0000e+00
# Epoch 10/100
# 449/449 - 0s - loss: 0.3194 - accuracy: 0.0000e+00
# Epoch 11/100
# 449/449 - 0s - loss: 0.3149 - accuracy: 0.0000e+00
# Epoch 12/100
# 449/449 - 0s - loss: 0.3087 - accuracy: 0.0000e+00
# Epoch 13/100
# 449/449 - 0s - loss: 0.3067 - accuracy: 0.0000e+00
# Epoch 14/100
# 449/449 - 0s - loss: 0.3030 - accuracy: 0.0000e+00
# Epoch 15/100
# 449/449 - 0s - loss: 0.3009 - accuracy: 0.0000e+00
# Epoch 16/100
# 449/449 - 0s - loss: 0.2985 - accuracy: 0.0000e+00
# Epoch 17/100
# 449/449 - 0s - loss: 0.2979 - accuracy: 0.0000e+00
# Epoch 18/100
# 449/449 - 0s - loss: 0.2958 - accuracy: 0.0000e+00
# Epoch 19/100
# 449/449 - 0s - loss: 0.2931 - accuracy: 0.0000e+00
# Epoch 20/100
# 449/449 - 0s - loss: 0.2922 - accuracy: 0.0000e+00
# Epoch 21/100
# 449/449 - 0s - loss: 0.2913 - accuracy: 0.0000e+00
# Epoch 22/100
# 449/449 - 0s - loss: 0.2895 - accuracy: 0.0000e+00
# Epoch 23/100
# 449/449 - 0s - loss: 0.2896 - accuracy: 0.0000e+00
# Epoch 24/100
# 449/449 - 0s - loss: 0.2875 - accuracy: 0.0000e+00
# Epoch 25/100
# 449/449 - 0s - loss: 0.2870 - accuracy: 0.0000e+00
# Epoch 26/100
# 449/449 - 0s - loss: 0.2873 - accuracy: 0.0000e+00
# Epoch 27/100
# 449/449 - 0s - loss: 0.2834 - accuracy: 0.0000e+00
# Epoch 28/100
# 449/449 - 0s - loss: 0.2827 - accuracy: 0.0000e+00
# Epoch 29/100
# 449/449 - 0s - loss: 0.2809 - accuracy: 0.0000e+00
# Epoch 30/100
# 449/449 - 0s - loss: 0.2804 - accuracy: 0.0000e+00
# Epoch 31/100
# 449/449 - 0s - loss: 0.2779 - accuracy: 0.0000e+00
# Epoch 32/100
# 449/449 - 0s - loss: 0.2786 - accuracy: 0.0000e+00
# Epoch 33/100
# 449/449 - 0s - loss: 0.2787 - accuracy: 0.0000e+00
# Epoch 34/100
# 449/449 - 0s - loss: 0.2740 - accuracy: 0.0000e+00
# Epoch 35/100
# 449/449 - 0s - loss: 0.2721 - accuracy: 0.0000e+00
# Epoch 36/100
# 449/449 - 0s - loss: 0.2718 - accuracy: 0.0000e+00
# Epoch 37/100
# 449/449 - 0s - loss: 0.2723 - accuracy: 0.0000e+00
# Epoch 38/100
# 449/449 - 0s - loss: 0.2694 - accuracy: 0.0000e+00
# Epoch 39/100
# 449/449 - 0s - loss: 0.2713 - accuracy: 0.0000e+00
# Epoch 40/100
# 449/449 - 0s - loss: 0.2679 - accuracy: 0.0000e+00
# Epoch 41/100
# 449/449 - 0s - loss: 0.2712 - accuracy: 0.0000e+00
# Epoch 42/100
# 449/449 - 0s - loss: 0.2667 - accuracy: 0.0000e+00
# Epoch 43/100
# 449/449 - 0s - loss: 0.2676 - accuracy: 0.0000e+00
# Epoch 44/100
# 449/449 - 0s - loss: 0.2649 - accuracy: 0.0000e+00
# Epoch 45/100
# 449/449 - 0s - loss: 0.2628 - accuracy: 0.0000e+00
# Epoch 46/100
# 449/449 - 0s - loss: 0.2639 - accuracy: 0.0000e+00
# Epoch 47/100
# 449/449 - 0s - loss: 0.2628 - accuracy: 0.0000e+00
# Epoch 48/100
# 449/449 - 0s - loss: 0.2629 - accuracy: 0.0000e+00
# Epoch 49/100
# 449/449 - 0s - loss: 0.2604 - accuracy: 0.0000e+00
# Epoch 50/100
# 449/449 - 0s - loss: 0.2610 - accuracy: 0.0000e+00
# Epoch 51/100
# 449/449 - 0s - loss: 0.2593 - accuracy: 0.0000e+00
# Epoch 52/100
# 449/449 - 0s - loss: 0.2586 - accuracy: 0.0000e+00
# Epoch 53/100
# 449/449 - 0s - loss: 0.2616 - accuracy: 0.0000e+00
# Epoch 54/100
# 449/449 - 0s - loss: 0.2575 - accuracy: 0.0000e+00
# Epoch 55/100
# 449/449 - 0s - loss: 0.2560 - accuracy: 0.0000e+00
# Epoch 56/100
# 449/449 - 0s - loss: 0.2594 - accuracy: 0.0000e+00
# Epoch 57/100
# 449/449 - 0s - loss: 0.2579 - accuracy: 0.0000e+00
# Epoch 58/100
# 449/449 - 0s - loss: 0.2544 - accuracy: 0.0000e+00
# Epoch 59/100
# 449/449 - 0s - loss: 0.2546 - accuracy: 0.0000e+00
# Epoch 60/100
# 449/449 - 0s - loss: 0.2576 - accuracy: 0.0000e+00
# Epoch 61/100
# 449/449 - 0s - loss: 0.2543 - accuracy: 0.0000e+00
# Epoch 62/100
# 449/449 - 0s - loss: 0.2563 - accuracy: 0.0000e+00
# Epoch 63/100
# 449/449 - 0s - loss: 0.2542 - accuracy: 0.0000e+00
# Epoch 64/100
# 449/449 - 0s - loss: 0.2529 - accuracy: 0.0000e+00
# Epoch 65/100
# 449/449 - 0s - loss: 0.2544 - accuracy: 0.0000e+00
# Epoch 66/100
# 449/449 - 0s - loss: 0.2553 - accuracy: 0.0000e+00
# Epoch 67/100
# 449/449 - 0s - loss: 0.2520 - accuracy: 0.0000e+00
# Epoch 68/100
# 449/449 - 0s - loss: 0.2529 - accuracy: 0.0000e+00
# Epoch 69/100
# 449/449 - 0s - loss: 0.2516 - accuracy: 0.0000e+00
# Epoch 70/100
# 449/449 - 0s - loss: 0.2511 - accuracy: 0.0000e+00
# Epoch 71/100
# 449/449 - 0s - loss: 0.2514 - accuracy: 0.0000e+00
# Epoch 72/100
# 449/449 - 0s - loss: 0.2489 - accuracy: 0.0000e+00
# Epoch 73/100
# 449/449 - 0s - loss: 0.2502 - accuracy: 0.0000e+00
# Epoch 74/100
# 449/449 - 0s - loss: 0.2500 - accuracy: 0.0000e+00
# Epoch 75/100
# 449/449 - 0s - loss: 0.2481 - accuracy: 0.0000e+00
# Epoch 76/100
# 449/449 - 0s - loss: 0.2496 - accuracy: 0.0000e+00
# Epoch 77/100
# 449/449 - 0s - loss: 0.2474 - accuracy: 0.0000e+00
# Epoch 78/100
# 449/449 - 0s - loss: 0.2480 - accuracy: 0.0000e+00
# Epoch 79/100
# 449/449 - 0s - loss: 0.2477 - accuracy: 0.0000e+00
# Epoch 80/100
# 449/449 - 0s - loss: 0.2480 - accuracy: 0.0000e+00
# Epoch 81/100
# 449/449 - 0s - loss: 0.2475 - accuracy: 0.0000e+00
# Epoch 82/100
# 449/449 - 0s - loss: 0.2462 - accuracy: 0.0000e+00
# Epoch 83/100
# 449/449 - 0s - loss: 0.2479 - accuracy: 0.0000e+00
# Epoch 84/100
# 449/449 - 0s - loss: 0.2491 - accuracy: 0.0000e+00
# Epoch 85/100
# 449/449 - 0s - loss: 0.2475 - accuracy: 0.0000e+00
# Epoch 86/100
# 449/449 - 0s - loss: 0.2477 - accuracy: 0.0000e+00
# Epoch 87/100
# 449/449 - 0s - loss: 0.2439 - accuracy: 0.0000e+00
# Epoch 88/100
# 449/449 - 0s - loss: 0.2440 - accuracy: 0.0000e+00
# Epoch 89/100
# 449/449 - 0s - loss: 0.2442 - accuracy: 0.0000e+00
# Epoch 90/100
# 449/449 - 0s - loss: 0.2452 - accuracy: 0.0000e+00
# Epoch 91/100
# 449/449 - 0s - loss: 0.2426 - accuracy: 0.0000e+00
# Epoch 92/100
# 449/449 - 0s - loss: 0.2435 - accuracy: 0.0000e+00
# Epoch 93/100
# 449/449 - 0s - loss: 0.2429 - accuracy: 0.0000e+00
# Epoch 94/100
# 449/449 - 0s - loss: 0.2428 - accuracy: 0.0000e+00
# Epoch 95/100
# 449/449 - 0s - loss: 0.2409 - accuracy: 0.0000e+00
# Epoch 96/100
# 449/449 - 0s - loss: 0.2411 - accuracy: 0.0000e+00
# Epoch 97/100
# 449/449 - 0s - loss: 0.2448 - accuracy: 0.0000e+00
# Epoch 98/100
# 449/449 - 0s - loss: 0.2426 - accuracy: 0.0000e+00
# Epoch 99/100
# 449/449 - 0s - loss: 0.2445 - accuracy: 0.0000e+00
# Epoch 100/100
# 449/449 - 0s - loss: 0.2398 - accuracy: 0.0000e+00
# 50/50 - 0s - loss: 0.4422 - accuracy: 0.0000e+00
# Train on 449 samples
# Epoch 1/100
# 449/449 - 0s - loss: 0.8507 - accuracy: 0.0000e+00
# Epoch 2/100
# 449/449 - 0s - loss: 0.5633 - accuracy: 0.0000e+00
# Epoch 3/100
# 449/449 - 0s - loss: 0.4392 - accuracy: 0.0000e+00
# Epoch 4/100
# 449/449 - 0s - loss: 0.4030 - accuracy: 0.0000e+00
# Epoch 5/100
# 449/449 - 0s - loss: 0.3806 - accuracy: 0.0000e+00
# Epoch 6/100
# 449/449 - 0s - loss: 0.3642 - accuracy: 0.0000e+00
# Epoch 7/100
# 449/449 - 0s - loss: 0.3521 - accuracy: 0.0000e+00
# Epoch 8/100
# 449/449 - 0s - loss: 0.3426 - accuracy: 0.0000e+00
# Epoch 9/100
# 449/449 - 0s - loss: 0.3359 - accuracy: 0.0000e+00
# Epoch 10/100
# 449/449 - 0s - loss: 0.3299 - accuracy: 0.0000e+00
# Epoch 11/100
# 449/449 - 0s - loss: 0.3245 - accuracy: 0.0000e+00
# Epoch 12/100
# 449/449 - 0s - loss: 0.3193 - accuracy: 0.0000e+00
# Epoch 13/100
# 449/449 - 0s - loss: 0.3188 - accuracy: 0.0000e+00
# Epoch 14/100
# 449/449 - 0s - loss: 0.3131 - accuracy: 0.0000e+00
# Epoch 15/100
# 449/449 - 0s - loss: 0.3128 - accuracy: 0.0000e+00
# Epoch 16/100
# 449/449 - 0s - loss: 0.3102 - accuracy: 0.0000e+00
# Epoch 17/100
# 449/449 - 0s - loss: 0.3080 - accuracy: 0.0000e+00
# Epoch 18/100
# 449/449 - 0s - loss: 0.3073 - accuracy: 0.0000e+00
# Epoch 19/100
# 449/449 - 0s - loss: 0.3059 - accuracy: 0.0000e+00
# Epoch 20/100
# 449/449 - 0s - loss: 0.3055 - accuracy: 0.0000e+00
# Epoch 21/100
# 449/449 - 0s - loss: 0.3041 - accuracy: 0.0000e+00
# Epoch 22/100
# 449/449 - 0s - loss: 0.3015 - accuracy: 0.0000e+00
# Epoch 23/100
# 449/449 - 0s - loss: 0.3001 - accuracy: 0.0000e+00
# Epoch 24/100
# 449/449 - 0s - loss: 0.3007 - accuracy: 0.0000e+00
# Epoch 25/100
# 449/449 - 0s - loss: 0.2981 - accuracy: 0.0000e+00
# Epoch 26/100
# 449/449 - 0s - loss: 0.2986 - accuracy: 0.0000e+00
# Epoch 27/100
# 449/449 - 0s - loss: 0.2983 - accuracy: 0.0000e+00
# Epoch 28/100
# 449/449 - 0s - loss: 0.2975 - accuracy: 0.0000e+00
# Epoch 29/100
# 449/449 - 0s - loss: 0.2956 - accuracy: 0.0000e+00
# Epoch 30/100
# 449/449 - 0s - loss: 0.2942 - accuracy: 0.0000e+00
# Epoch 31/100
# 449/449 - 0s - loss: 0.2929 - accuracy: 0.0000e+00
# Epoch 32/100
# 449/449 - 0s - loss: 0.2925 - accuracy: 0.0000e+00
# Epoch 33/100
# 449/449 - 0s - loss: 0.2922 - accuracy: 0.0000e+00
# Epoch 34/100
# 449/449 - 0s - loss: 0.2919 - accuracy: 0.0000e+00
# Epoch 35/100
# 449/449 - 0s - loss: 0.2893 - accuracy: 0.0000e+00
# Epoch 36/100
# 449/449 - 0s - loss: 0.2885 - accuracy: 0.0000e+00
# Epoch 37/100
# 449/449 - 0s - loss: 0.2882 - accuracy: 0.0000e+00
# Epoch 38/100
# 449/449 - 0s - loss: 0.2864 - accuracy: 0.0000e+00
# Epoch 39/100
# 449/449 - 0s - loss: 0.2855 - accuracy: 0.0000e+00
# Epoch 40/100
# 449/449 - 0s - loss: 0.2855 - accuracy: 0.0000e+00
# Epoch 41/100
# 449/449 - 0s - loss: 0.2834 - accuracy: 0.0000e+00
# Epoch 42/100
# 449/449 - 0s - loss: 0.2851 - accuracy: 0.0000e+00
# Epoch 43/100
# 449/449 - 0s - loss: 0.2857 - accuracy: 0.0000e+00
# ...
# 449/449 - 0s - loss: 0.2781 - accuracy: 0.0000e+00
# Epoch 55/100
# 449/449 - 0s - loss: 0.2772 - accuracy: 0.0000e+00
# Epoch 56/100
# 449/449 - 0s - loss: 0.2746 - accuracy: 0.0000e+00
# Epoch 57/100
# 449/449 - 0s - loss: 0.2760 - accuracy: 0.0000e+00
# Epoch 58/100
# 449/449 - 0s - loss: 0.2746 - accuracy: 0.0000e+00
# Epoch 59/100
# 449/449 - 0s - loss: 0.2758 - accuracy: 0.0000e+00
# Epoch 60/100
# 449/449 - 0s - loss: 0.2767 - accuracy: 0.0000e+00
# Epoch 61/100
# 449/449 - 0s - loss: 0.2746 - accuracy: 0.0000e+00
# Epoch 62/100
# 449/449 - 0s - loss: 0.2733 - accuracy: 0.0000e+00
# Epoch 63/100
# 449/449 - 0s - loss: 0.2736 - accuracy: 0.0000e+00
# Epoch 64/100
# 449/449 - 0s - loss: 0.2718 - accuracy: 0.0000e+00
# Epoch 65/100
# 449/449 - 0s - loss: 0.2762 - accuracy: 0.0000e+00
# Epoch 66/100
# 449/449 - 0s - loss: 0.2712 - accuracy: 0.0000e+00
# Epoch 67/100
# 449/449 - 0s - loss: 0.2729 - accuracy: 0.0000e+00
# Epoch 68/100
# 449/449 - 0s - loss: 0.2713 - accuracy: 0.0000e+00
# Epoch 69/100
# 449/449 - 0s - loss: 0.2726 - accuracy: 0.0000e+00
# Epoch 70/100
# 449/449 - 0s - loss: 0.2737 - accuracy: 0.0000e+00
# Epoch 71/100
# 449/449 - 0s - loss: 0.2713 - accuracy: 0.0000e+00
# Epoch 72/100
# 449/449 - 0s - loss: 0.2709 - accuracy: 0.0000e+00
# Epoch 73/100
# 449/449 - 0s - loss: 0.2706 - accuracy: 0.0000e+00
# Epoch 74/100
# 449/449 - 0s - loss: 0.2705 - accuracy: 0.0000e+00
# Epoch 75/100
# 449/449 - 0s - loss: 0.2695 - accuracy: 0.0000e+00
# Epoch 76/100
# 449/449 - 0s - loss: 0.2712 - accuracy: 0.0000e+00
# Epoch 77/100
# 449/449 - 0s - loss: 0.2675 - accuracy: 0.0000e+00
# Epoch 78/100
# 449/449 - 0s - loss: 0.2685 - accuracy: 0.0000e+00
# Epoch 79/100
# 449/449 - 0s - loss: 0.2670 - accuracy: 0.0000e+00
# Epoch 80/100
# 449/449 - 0s - loss: 0.2701 - accuracy: 0.0000e+00
# Epoch 81/100
# 449/449 - 0s - loss: 0.2686 - accuracy: 0.0000e+00
# Epoch 82/100
# 449/449 - 0s - loss: 0.2678 - accuracy: 0.0000e+00
# Epoch 83/100
# 449/449 - 0s - loss: 0.2689 - accuracy: 0.0000e+00
# Epoch 84/100
# 449/449 - 0s - loss: 0.2681 - accuracy: 0.0000e+00
# Epoch 85/100
# 449/449 - 0s - loss: 0.2657 - accuracy: 0.0000e+00
# Epoch 86/100
# 449/449 - 0s - loss: 0.2678 - accuracy: 0.0000e+00
# Epoch 87/100
# 449/449 - 0s - loss: 0.2683 - accuracy: 0.0000e+00
# Epoch 88/100
# 449/449 - 0s - loss: 0.2650 - accuracy: 0.0000e+00
# Epoch 89/100
# 449/449 - 0s - loss: 0.2636 - accuracy: 0.0000e+00
# Epoch 90/100
# 449/449 - 0s - loss: 0.2640 - accuracy: 0.0000e+00
# Epoch 91/100
# 449/449 - 0s - loss: 0.2645 - accuracy: 0.0000e+00
# Epoch 92/100
# 449/449 - 0s - loss: 0.2628 - accuracy: 0.0000e+00
# Epoch 93/100
# 449/449 - 0s - loss: 0.2659 - accuracy: 0.0000e+00
# Epoch 94/100
# 449/449 - 0s - loss: 0.2642 - accuracy: 0.0000e+00
# Epoch 95/100
# 449/449 - 0s - loss: 0.2648 - accuracy: 0.0000e+00
# Epoch 96/100
# 449/449 - 0s - loss: 0.2622 - accuracy: 0.0000e+00
# Epoch 97/100
# 449/449 - 0s - loss: 0.2624 - accuracy: 0.0000e+00
# Epoch 98/100
# 449/449 - 0s - loss: 0.2633 - accuracy: 0.0000e+00
# Epoch 99/100
# 449/449 - 0s - loss: 0.2623 - accuracy: 0.0000e+00
# Epoch 100/100
# 449/449 - 0s - loss: 0.2661 - accuracy: 0.0000e+00
# 50/50 - 0s - loss: 0.2565 - accuracy: 0.0000e+00
# Train on 449 samples
# Epoch 1/100
# 449/449 - 0s - loss: 0.9081 - accuracy: 0.0000e+00
# Epoch 2/100
# 449/449 - 0s - loss: 0.5637 - accuracy: 0.0000e+00
# Epoch 3/100
# 449/449 - 0s - loss: 0.4351 - accuracy: 0.0000e+00
# Epoch 4/100
# 449/449 - 0s - loss: 0.3968 - accuracy: 0.0000e+00
# Epoch 5/100
# 449/449 - 0s - loss: 0.3720 - accuracy: 0.0000e+00
# Epoch 6/100
# 449/449 - 0s - loss: 0.3558 - accuracy: 0.0000e+00
# Epoch 7/100
# 449/449 - 0s - loss: 0.3427 - accuracy: 0.0000e+00
# Epoch 8/100
# 449/449 - 0s - loss: 0.3341 - accuracy: 0.0000e+00
# Epoch 9/100
# 449/449 - 0s - loss: 0.3290 - accuracy: 0.0000e+00
# Epoch 10/100
# 449/449 - 0s - loss: 0.3227 - accuracy: 0.0000e+00
# Epoch 11/100
# 449/449 - 0s - loss: 0.3185 - accuracy: 0.0000e+00
# Epoch 12/100
# 449/449 - 0s - loss: 0.3154 - accuracy: 0.0000e+00
# Epoch 13/100
# 449/449 - 0s - loss: 0.3124 - accuracy: 0.0000e+00
# Epoch 14/100
# 449/449 - 0s - loss: 0.3122 - accuracy: 0.0000e+00
# Epoch 15/100
# 449/449 - 0s - loss: 0.3084 - accuracy: 0.0000e+00
# Epoch 16/100
# 449/449 - 0s - loss: 0.3078 - accuracy: 0.0000e+00
# Epoch 17/100
# 449/449 - 0s - loss: 0.3055 - accuracy: 0.0000e+00
# Epoch 18/100
# 449/449 - 0s - loss: 0.3034 - accuracy: 0.0000e+00
# Epoch 19/100
# 449/449 - 0s - loss: 0.3030 - accuracy: 0.0000e+00
# Epoch 20/100
# 449/449 - 0s - loss: 0.3043 - accuracy: 0.0000e+00
# Epoch 21/100
# 449/449 - 0s - loss: 0.3028 - accuracy: 0.0000e+00
# Epoch 22/100
# 449/449 - 0s - loss: 0.3000 - accuracy: 0.0000e+00
# Epoch 23/100
# 449/449 - 0s - loss: 0.2964 - accuracy: 0.0000e+00
# Epoch 24/100
# 449/449 - 0s - loss: 0.2950 - accuracy: 0.0000e+00
# Epoch 25/100
# 449/449 - 0s - loss: 0.2935 - accuracy: 0.0000e+00
# Epoch 26/100
# 449/449 - 0s - loss: 0.2934 - accuracy: 0.0000e+00
# Epoch 27/100
# 449/449 - 0s - loss: 0.2925 - accuracy: 0.0000e+00
# Epoch 28/100
# 449/449 - 0s - loss: 0.2924 - accuracy: 0.0000e+00
# Epoch 29/100
# 449/449 - 0s - loss: 0.2914 - accuracy: 0.0000e+00
# Epoch 30/100
# 449/449 - 0s - loss: 0.2905 - accuracy: 0.0000e+00
# Epoch 31/100
# 449/449 - 0s - loss: 0.2880 - accuracy: 0.0000e+00
# Epoch 32/100
# 449/449 - 0s - loss: 0.2870 - accuracy: 0.0000e+00
# Epoch 33/100
# 449/449 - 0s - loss: 0.2859 - accuracy: 0.0000e+00
# Epoch 34/100
# 449/449 - 0s - loss: 0.2834 - accuracy: 0.0000e+00
# Epoch 35/100
# 449/449 - 0s - loss: 0.2833 - accuracy: 0.0000e+00
# Epoch 36/100
# 449/449 - 0s - loss: 0.2829 - accuracy: 0.0000e+00
# Epoch 37/100
# 449/449 - 0s - loss: 0.2806 - accuracy: 0.0000e+00
# Epoch 38/100
# 449/449 - 0s - loss: 0.2792 - accuracy: 0.0000e+00
# Epoch 39/100
# 449/449 - 0s - loss: 0.2815 - accuracy: 0.0000e+00
# Epoch 40/100
# 449/449 - 0s - loss: 0.2839 - accuracy: 0.0000e+00
# Epoch 41/100
# 449/449 - 0s - loss: 0.2779 - accuracy: 0.0000e+00
# Epoch 42/100
# 449/449 - 0s - loss: 0.2765 - accuracy: 0.0000e+00
# Epoch 43/100
# 449/449 - 0s - loss: 0.2849 - accuracy: 0.0000e+00
# Epoch 44/100
# 449/449 - 0s - loss: 0.2792 - accuracy: 0.0000e+00
# Epoch 45/100
# 449/449 - 0s - loss: 0.2798 - accuracy: 0.0000e+00
# Epoch 46/100
# 449/449 - 0s - loss: 0.2779 - accuracy: 0.0000e+00
# Epoch 47/100
# 449/449 - 0s - loss: 0.2751 - accuracy: 0.0000e+00
# Epoch 48/100
# 449/449 - 0s - loss: 0.2741 - accuracy: 0.0000e+00
# Epoch 49/100
# 449/449 - 0s - loss: 0.2757 - accuracy: 0.0000e+00
# Epoch 50/100
# 449/449 - 0s - loss: 0.2721 - accuracy: 0.0000e+00
# Epoch 51/100
# 449/449 - 0s - loss: 0.2712 - accuracy: 0.0000e+00
# Epoch 52/100
# 449/449 - 0s - loss: 0.2736 - accuracy: 0.0000e+00
# Epoch 53/100
# 449/449 - 0s - loss: 0.2760 - accuracy: 0.0000e+00
# Epoch 54/100
# 449/449 - 0s - loss: 0.2720 - accuracy: 0.0000e+00
# Epoch 55/100
# 449/449 - 0s - loss: 0.2736 - accuracy: 0.0000e+00
# Epoch 56/100
# 449/449 - 0s - loss: 0.2702 - accuracy: 0.0000e+00
# Epoch 57/100
# 449/449 - 0s - loss: 0.2715 - accuracy: 0.0000e+00
# Epoch 58/100
# 449/449 - 0s - loss: 0.2715 - accuracy: 0.0000e+00
# Epoch 59/100
# 449/449 - 0s - loss: 0.2683 - accuracy: 0.0000e+00
# Epoch 60/100
# 449/449 - 0s - loss: 0.2713 - accuracy: 0.0000e+00
# Epoch 61/100
# 449/449 - 0s - loss: 0.2712 - accuracy: 0.0000e+00
# Epoch 62/100
# 449/449 - 0s - loss: 0.2687 - accuracy: 0.0000e+00
# Epoch 63/100
# 449/449 - 0s - loss: 0.2695 - accuracy: 0.0000e+00
# Epoch 64/100
# 449/449 - 0s - loss: 0.2669 - accuracy: 0.0000e+00
# Epoch 65/100
# 449/449 - 0s - loss: 0.2686 - accuracy: 0.0000e+00
# Epoch 66/100
# 449/449 - 0s - loss: 0.2668 - accuracy: 0.0000e+00
# Epoch 67/100
# 449/449 - 0s - loss: 0.2691 - accuracy: 0.0000e+00
# Epoch 68/100
# 449/449 - 0s - loss: 0.2670 - accuracy: 0.0000e+00
# Epoch 69/100
# 449/449 - 0s - loss: 0.2666 - accuracy: 0.0000e+00
# Epoch 70/100
# 449/449 - 0s - loss: 0.2653 - accuracy: 0.0000e+00
# Epoch 71/100
# 449/449 - 0s - loss: 0.2662 - accuracy: 0.0000e+00
# Epoch 72/100
# 449/449 - 0s - loss: 0.2659 - accuracy: 0.0000e+00
# Epoch 73/100
# 449/449 - 0s - loss: 0.2668 - accuracy: 0.0000e+00
# Epoch 74/100
# 449/449 - 0s - loss: 0.2666 - accuracy: 0.0000e+00
# Epoch 75/100
# 449/449 - 0s - loss: 0.2658 - accuracy: 0.0000e+00
# Epoch 76/100
# 449/449 - 0s - loss: 0.2669 - accuracy: 0.0000e+00
# Epoch 77/100
# 449/449 - 0s - loss: 0.2608 - accuracy: 0.0000e+00
# Epoch 78/100
# 449/449 - 0s - loss: 0.2650 - accuracy: 0.0000e+00
# Epoch 79/100
# 449/449 - 0s - loss: 0.2655 - accuracy: 0.0000e+00
# Epoch 80/100
# 449/449 - 0s - loss: 0.2623 - accuracy: 0.0000e+00
# Epoch 81/100
# 449/449 - 0s - loss: 0.2625 - accuracy: 0.0000e+00
# Epoch 82/100
# 449/449 - 0s - loss: 0.2631 - accuracy: 0.0000e+00
# Epoch 83/100
# 449/449 - 0s - loss: 0.2630 - accuracy: 0.0000e+00
# Epoch 84/100
# 449/449 - 0s - loss: 0.2603 - accuracy: 0.0000e+00
# Epoch 85/100
# 449/449 - 0s - loss: 0.2626 - accuracy: 0.0000e+00
# Epoch 86/100
# 449/449 - 0s - loss: 0.2607 - accuracy: 0.0000e+00
# Epoch 87/100
# 449/449 - 0s - loss: 0.2610 - accuracy: 0.0000e+00
# Epoch 88/100
# 449/449 - 0s - loss: 0.2605 - accuracy: 0.0000e+00
# Epoch 89/100
# 449/449 - 0s - loss: 0.2581 - accuracy: 0.0000e+00
# Epoch 90/100
# 449/449 - 0s - loss: 0.2614 - accuracy: 0.0000e+00
# Epoch 91/100
# 449/449 - 0s - loss: 0.2575 - accuracy: 0.0000e+00
# Epoch 92/100
# 449/449 - 0s - loss: 0.2578 - accuracy: 0.0000e+00
# Epoch 93/100
# 449/449 - 0s - loss: 0.2567 - accuracy: 0.0000e+00
# Epoch 94/100
# 449/449 - 0s - loss: 0.2552 - accuracy: 0.0000e+00
# Epoch 95/100
# 449/449 - 0s - loss: 0.2580 - accuracy: 0.0000e+00
# Epoch 96/100
# 449/449 - 0s - loss: 0.2578 - accuracy: 0.0000e+00
# Epoch 97/100
# 449/449 - 0s - loss: 0.2570 - accuracy: 0.0000e+00
# Epoch 98/100
# 449/449 - 0s - loss: 0.2567 - accuracy: 0.0000e+00
# Epoch 99/100
# 449/449 - 0s - loss: 0.2524 - accuracy: 0.0000e+00
# Epoch 100/100
# 449/449 - 0s - loss: 0.2544 - accuracy: 0.0000e+00
# 50/50 - 0s - loss: 0.2747 - accuracy: 0.0000e+00
# Train on 450 samples
# Epoch 1/100
# 450/450 - 0s - loss: 0.9097 - accuracy: 0.0000e+00
# Epoch 2/100
# 450/450 - 0s - loss: 0.5991 - accuracy: 0.0000e+00
# Epoch 3/100
# 450/450 - 0s - loss: 0.4608 - accuracy: 0.0000e+00
# Epoch 4/100
# 450/450 - 0s - loss: 0.4082 - accuracy: 0.0000e+00
# Epoch 5/100
# 450/450 - 0s - loss: 0.3793 - accuracy: 0.0000e+00
# Epoch 6/100
# 450/450 - 0s - loss: 0.3582 - accuracy: 0.0000e+00
# Epoch 7/100
# 450/450 - 0s - loss: 0.3491 - accuracy: 0.0000e+00
# Epoch 8/100
# 450/450 - 0s - loss: 0.3377 - accuracy: 0.0000e+00
# Epoch 9/100
# 450/450 - 0s - loss: 0.3305 - accuracy: 0.0000e+00
# Epoch 10/100
# 450/450 - 0s - loss: 0.3244 - accuracy: 0.0000e+00
# Epoch 11/100
# 450/450 - 0s - loss: 0.3206 - accuracy: 0.0000e+00
# Epoch 12/100
# 450/450 - 0s - loss: 0.3177 - accuracy: 0.0000e+00
# Epoch 13/100
# 450/450 - 0s - loss: 0.3146 - accuracy: 0.0000e+00
# Epoch 14/100
# 450/450 - 0s - loss: 0.3140 - accuracy: 0.0000e+00
# Epoch 15/100
# 450/450 - 0s - loss: 0.3109 - accuracy: 0.0000e+00
# Epoch 16/100
# 450/450 - 0s - loss: 0.3091 - accuracy: 0.0000e+00
# Epoch 17/100
# 450/450 - 0s - loss: 0.3062 - accuracy: 0.0000e+00
# Epoch 18/100
# 450/450 - 0s - loss: 0.3084 - accuracy: 0.0000e+00
# Epoch 19/100
# 450/450 - 0s - loss: 0.3045 - accuracy: 0.0000e+00
# Epoch 20/100
# 450/450 - 0s - loss: 0.3033 - accuracy: 0.0000e+00
# Epoch 21/100
# 450/450 - 0s - loss: 0.2998 - accuracy: 0.0000e+00
# Epoch 22/100
# 450/450 - 0s - loss: 0.2967 - accuracy: 0.0000e+00
# Epoch 23/100
# 450/450 - 0s - loss: 0.2967 - accuracy: 0.0000e+00
# Epoch 24/100
# 450/450 - 0s - loss: 0.2953 - accuracy: 0.0000e+00
# Epoch 25/100
# 450/450 - 0s - loss: 0.2939 - accuracy: 0.0000e+00
# Epoch 26/100
# 450/450 - 0s - loss: 0.2909 - accuracy: 0.0000e+00
# Epoch 27/100
# 450/450 - 0s - loss: 0.2897 - accuracy: 0.0000e+00
# Epoch 28/100
# 450/450 - 0s - loss: 0.2890 - accuracy: 0.0000e+00
# Epoch 29/100
# 450/450 - 0s - loss: 0.2876 - accuracy: 0.0000e+00
# Epoch 30/100
# 450/450 - 0s - loss: 0.2858 - accuracy: 0.0000e+00
# Epoch 31/100
# 450/450 - 0s - loss: 0.2844 - accuracy: 0.0000e+00
# Epoch 32/100
# 450/450 - 0s - loss: 0.2837 - accuracy: 0.0000e+00
# Epoch 33/100
# 450/450 - 0s - loss: 0.2820 - accuracy: 0.0000e+00
# Epoch 34/100
# 450/450 - 0s - loss: 0.2804 - accuracy: 0.0000e+00
# Epoch 35/100
# 450/450 - 0s - loss: 0.2795 - accuracy: 0.0000e+00
# Epoch 36/100
# 450/450 - 0s - loss: 0.2777 - accuracy: 0.0000e+00
# Epoch 37/100
# 450/450 - 0s - loss: 0.2788 - accuracy: 0.0000e+00
# Epoch 38/100
# 450/450 - 0s - loss: 0.2764 - accuracy: 0.0000e+00
# Epoch 39/100
# 450/450 - 0s - loss: 0.2754 - accuracy: 0.0000e+00
# Epoch 40/100
# 450/450 - 0s - loss: 0.2730 - accuracy: 0.0000e+00
# Epoch 41/100
# 450/450 - 0s - loss: 0.2749 - accuracy: 0.0000e+00
# Epoch 42/100
# 450/450 - 0s - loss: 0.2723 - accuracy: 0.0000e+00
# Epoch 43/100
# 450/450 - 0s - loss: 0.2710 - accuracy: 0.0000e+00
# Epoch 44/100
# 450/450 - 0s - loss: 0.2692 - accuracy: 0.0000e+00
# Epoch 45/100
# 450/450 - 0s - loss: 0.2703 - accuracy: 0.0000e+00
# Epoch 46/100
# 450/450 - 0s - loss: 0.2688 - accuracy: 0.0000e+00
# Epoch 47/100
# 450/450 - 0s - loss: 0.2702 - accuracy: 0.0000e+00
# Epoch 48/100
# 450/450 - 0s - loss: 0.2666 - accuracy: 0.0000e+00
# Epoch 49/100
# 450/450 - 0s - loss: 0.2667 - accuracy: 0.0000e+00
# Epoch 50/100
# 450/450 - 0s - loss: 0.2683 - accuracy: 0.0000e+00
# Epoch 51/100
# 450/450 - 0s - loss: 0.2665 - accuracy: 0.0000e+00
# Epoch 52/100
# 450/450 - 0s - loss: 0.2649 - accuracy: 0.0000e+00
# Epoch 53/100
# 450/450 - 0s - loss: 0.2625 - accuracy: 0.0000e+00
# Epoch 54/100
# 450/450 - 0s - loss: 0.2623 - accuracy: 0.0000e+00
# Epoch 55/100
# 450/450 - 0s - loss: 0.2616 - accuracy: 0.0000e+00
# Epoch 56/100
# 450/450 - 0s - loss: 0.2631 - accuracy: 0.0000e+00
# Epoch 57/100
# 450/450 - 0s - loss: 0.2619 - accuracy: 0.0000e+00
# Epoch 58/100
# 450/450 - 0s - loss: 0.2603 - accuracy: 0.0000e+00
# Epoch 59/100
# 450/450 - 0s - loss: 0.2620 - accuracy: 0.0000e+00
# Epoch 60/100
# 450/450 - 0s - loss: 0.2589 - accuracy: 0.0000e+00
# Epoch 61/100
# 450/450 - 0s - loss: 0.2604 - accuracy: 0.0000e+00
# Epoch 62/100
# 450/450 - 0s - loss: 0.2598 - accuracy: 0.0000e+00
# Epoch 63/100
# 450/450 - 0s - loss: 0.2600 - accuracy: 0.0000e+00
# Epoch 64/100
# 450/450 - 0s - loss: 0.2599 - accuracy: 0.0000e+00
# Epoch 65/100
# 450/450 - 0s - loss: 0.2559 - accuracy: 0.0000e+00
# Epoch 66/100
# 450/450 - 0s - loss: 0.2549 - accuracy: 0.0000e+00
# Epoch 67/100
# 450/450 - 0s - loss: 0.2544 - accuracy: 0.0000e+00
# Epoch 68/100
# 450/450 - 0s - loss: 0.2553 - accuracy: 0.0000e+00
# Epoch 69/100
# 450/450 - 0s - loss: 0.2547 - accuracy: 0.0000e+00
# Epoch 70/100
# 450/450 - 0s - loss: 0.2531 - accuracy: 0.0000e+00
# Epoch 71/100
# 450/450 - 0s - loss: 0.2527 - accuracy: 0.0000e+00
# Epoch 72/100
# 450/450 - 0s - loss: 0.2530 - accuracy: 0.0000e+00
# Epoch 73/100
# 450/450 - 0s - loss: 0.2539 - accuracy: 0.0000e+00
# Epoch 74/100
# 450/450 - 0s - loss: 0.2499 - accuracy: 0.0000e+00
# Epoch 75/100
# 450/450 - 0s - loss: 0.2489 - accuracy: 0.0000e+00
# Epoch 76/100
# 450/450 - 0s - loss: 0.2504 - accuracy: 0.0000e+00
# Epoch 77/100
# 450/450 - 0s - loss: 0.2511 - accuracy: 0.0000e+00
# Epoch 78/100
# 450/450 - 0s - loss: 0.2490 - accuracy: 0.0000e+00
# Epoch 79/100
# 450/450 - 0s - loss: 0.2483 - accuracy: 0.0000e+00
# Epoch 80/100
# 450/450 - 0s - loss: 0.2484 - accuracy: 0.0000e+00
# Epoch 81/100
# 450/450 - 0s - loss: 0.2477 - accuracy: 0.0000e+00
# Epoch 82/100
# 450/450 - 0s - loss: 0.2474 - accuracy: 0.0000e+00
# Epoch 83/100
# 450/450 - 0s - loss: 0.2468 - accuracy: 0.0000e+00
# Epoch 84/100
# 450/450 - 0s - loss: 0.2476 - accuracy: 0.0000e+00
# Epoch 85/100
# 450/450 - 0s - loss: 0.2462 - accuracy: 0.0000e+00
# Epoch 86/100
# 450/450 - 0s - loss: 0.2476 - accuracy: 0.0000e+00
# Epoch 87/100
# 450/450 - 0s - loss: 0.2446 - accuracy: 0.0000e+00
# Epoch 88/100
# 450/450 - 0s - loss: 0.2473 - accuracy: 0.0000e+00
# Epoch 89/100
# 450/450 - 0s - loss: 0.2446 - accuracy: 0.0000e+00
# Epoch 90/100
# 450/450 - 0s - loss: 0.2431 - accuracy: 0.0000e+00
# Epoch 91/100
# 450/450 - 0s - loss: 0.2431 - accuracy: 0.0000e+00
# Epoch 92/100
# 450/450 - 0s - loss: 0.2438 - accuracy: 0.0000e+00
# Epoch 93/100
# 450/450 - 0s - loss: 0.2440 - accuracy: 0.0000e+00
# Epoch 94/100
# 450/450 - 0s - loss: 0.2412 - accuracy: 0.0000e+00
# Epoch 95/100
# 450/450 - 0s - loss: 0.2417 - accuracy: 0.0000e+00
# Epoch 96/100
# 450/450 - 0s - loss: 0.2412 - accuracy: 0.0000e+00
# Epoch 97/100
# 450/450 - 0s - loss: 0.2411 - accuracy: 0.0000e+00
# Epoch 98/100
# 450/450 - 0s - loss: 0.2380 - accuracy: 0.0000e+00
# Epoch 99/100
# 450/450 - 0s - loss: 0.2390 - accuracy: 0.0000e+00
# Epoch 100/100
# 450/450 - 0s - loss: 0.2400 - accuracy: 0.0000e+00
# 49/49 - 0s - loss: 0.3923 - accuracy: 0.0000e+00
# Results: -0.33 (0.12) MSE

# %%
import seaborn as sns
sns.pairplot(ML_df[['building/rooms/bathstotal','med/housing','bachper','summary/yearbuilt', 'perc_fs']])

# %%
ML_df1['sale/amount/saleamt'].apply(lambda x: np.log1p(x)**2).hist(bins=50,label='a')
plt.legend()

# %%
ML_df.hist(bins=50,figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001437C1D9978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001437B8D5278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001437B2C9470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001437BC169B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001437D704F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001437C468390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001437C467898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001437BDEAE48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001437BDEAE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001437B874940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001437C2D8EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000014379C2C470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000014379C1F9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000014379AA3F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001437B33F518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001437BFCBA90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001437BFA6048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001437C0405C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001437B7F5B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000014379C040F0>]],
#       dtype=object)
